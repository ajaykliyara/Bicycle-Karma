# %% [markdown]
# # Classification and prediction

# %% [markdown]
# ## Introduction
#
# This notebook is the first part to the project; Bicycle Karma: Predicting and tracking bike theft. The dataset was obtained from https://bikeindex.org via the provided API. The objective of this ipython notebook is to understand whether the bikes in the dataset can be classified as "stolen" or "not stolen", given the features of the bikes by running machine learning algorithms.
#
# This project aims to identify the key features or factors that contributed to bike theft in the past and to construct a bike theft prediction model
#
# This part deals with data cleansing, exploring the dataset and features through visualizations, running classification models, and evaluation of each classification model.Each classification model was validated and evaluated by ROC curves, sensitivity, specificity, and accuracy scores
#
# ## Classification
#
# Classification is the most widely used technique in data mining to construct models and to predict the outcome in unseen data. Even though the bike theft occurs due to random factors, this project aims to use different classifiers in order to identify the other key factors that could have played a role in the bike getting stolen.
#
# The supervised Machine learning algorithms used in this analysis are:
# 1. Decision Tree
# 2. Random Forest
# 3. Bagging
# 4. Logistic regression model
# 5. Support Vector Machine (SVM)
#
# In the following sections, these classifiers are explored and the plots and results are presented for the same

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Preliminary Data Analysis
#
# After obtaining all available data through API calls, the first step was ofcourse evaluating our  dataset and also defining the scope of our analysis through this process. To drive our group conversations, we created a summary spreadsheet of the data ([Data Dictionary](https://docs.google.com/spreadsheets/d/1EAWIMkVafj-bm9-3bTq5vi2PMjIJuN9Pz_62JCg7p-4/edit?usp=sharing)) to collect our thoughts in a central place
#
# We did some brain storming to identify and mark attributes that are to be within our scope of analysis. We decided to remove some columns from the dataset which fell into one of the following categories
# 1. Did not contain data which was not relavent for the problem we were trying to solve.
# 2. The feature is relevant, but the data was too sparse
# 3. The feature is relevant, but redundant in that the information represent is already available in a better fashion in another column.
#
# Also, following are some ideas which we considered based on the data that could be obtained additionally , but decided not to pursue in the interest of time.
#
# 1) Crime rate information : The zip code along with year could be used to derive the crime rate information of that county and could have helped examine the correlation of crime rate and bike theft. The Crimescore API (https://market.mashape.com/yourmapper/crimescore) was apt for this task but the API was not free. Hence we did not explore this option further.
#
# 2) Weather data : Lat/Long data can be used to look up weather information on the date on which bike was stolen, thus helping analyze role of weather in a bike theft. However we decided not to pursue this path, because of two reasons
#     i ) The historical weather data was not available freely and could be obtained through pay-per-use API's. We evaluated all of the API's listed at -http://stackoverflow.com/questions/2368722/are-there-any-weather-history-apis and also did some search on our own as well
#     ii ) Exact time of theft ( noon/evening/night etc) was not available in the dataset.
#
# 3) Points of Interest(POI): POIs near the lat/long of stolen location could be analyzed for common patterns. We decided that this a "good to have" and revisit it after analyzing other low hanging fruits in the interest of time.

# %% [markdown]
# ## Data Handling

# %%
df = pd.read_csv("bike_details_csv.csv")
df.head()
# Out:
#    Unnamed: 0     id                                       title          serial manufacturer_name                frame_model  year                                              thumb                                          large_img is_stock_img stolen      stolen_location          date_stolen registration_created_at registration_updated_at                                url                                   api_url  manufacturer_id paint_description name frame_size  \
# 0           0  50088                             Schwinn Gateway          absent           Schwinn                    Gateway   NaN                                                NaN                                                NaN        False  False                  NaN  1970-01-01 00:00:00     2015-07-06 22:27:01     2015-11-03 05:36:54  https://bikeindex.org/bikes/50088  https://bikeindex.org/api/v1/bikes/50088              117               NaN  NaN        NaN
# 1           1  60140          2016 Specialized Diverge Elite DSW  WSBC601010269K       Specialized          Diverge Elite DSW  2016                                                NaN                                                NaN        False  False                  NaN  1970-01-01 00:00:00     2015-10-08 19:18:50     2015-11-03 05:34:30  https://bikeindex.org/bikes/60140  https://bikeindex.org/api/v1/bikes/60140              307               NaN  NaN       52cm
# 2           2  44884  2016 Specialized '15 Crosstrail Sport Disc  WSBC606249640J       Specialized  '15 Crosstrail Sport Disc  2016                                                NaN                                                NaN        False  False                  NaN  1970-01-01 00:00:00     2015-05-08 00:30:25     2015-11-03 05:32:55  https://bikeindex.org/bikes/44884  https://bikeindex.org/api/v1/bikes/44884              307      Blk/Char/Red  NaN         xl
# 3           3  11542                              2013 Trek 4300    WTU124C5170G              Trek                       4300  2013                                                NaN                                                NaN        False   True  San Jose, CA, 95126  2013-06-10 06:00:00     2013-08-20 06:00:00     2015-11-03 05:11:14  https://bikeindex.org/bikes/11542  https://bikeindex.org/api/v1/bikes/11542               47               NaN  NaN        NaN
# 4           4  13359                         2010 Schwinn Katana          absent           Schwinn                     Katana  2010  https://files.bikeindex.org/uploads/Pu/4903/sm...  https://files.bikeindex.org/uploads/Pu/4903/la...        False   True  Sandusky, OH, 44870  2010-07-10 06:00:00     2010-07-11 06:00:00     2015-11-03 05:17:53  https://bikeindex.org/bikes/13359  https://bikeindex.org/api/v1/bikes/13359              117               NaN  NaN       58cm
#
#                                          description rear_tire_narrow front_tire_narrow type_of_cycle test_bike  rear_wheel_size_iso_bsd  front_wheel_size_iso_bsd handlebar_type_slug frame_material_slug front_gear_type_slug rear_gear_type_slug  stolen_id  s_date_stolen           s_location   latitude   longitude          theft_description locking_description lock_defeat_description police_report_number police_report_department     s_rec_created_at create_open311  \
# 0                                                NaN             True               NaN          Bike     False                      NaN                       NaN                 NaN                 NaN                  NaN                 NaN        NaN            NaN                  NaN        NaN         NaN                        NaN                 NaN                     NaN                  NaN                      NaN  1970-01-01 00:00:00            NaN
# 1                                                NaN             True               NaN          Bike     False                      NaN                       NaN                 NaN            aluminum                  NaN                 NaN        NaN            NaN                  NaN        NaN         NaN                        NaN                 NaN                     NaN                  NaN                      NaN  1970-01-01 00:00:00            NaN
# 2                          '15 Crosstrail Sport Disc             True               NaN          Bike     False                      NaN                       NaN                 NaN                 NaN                  NaN                 NaN        NaN            NaN                  NaN        NaN         NaN                        NaN                 NaN                     NaN                  NaN                      NaN  1970-01-01 00:00:00            NaN
# 3  Trek 4300, Mountain bicycle, disc brakes, blac...             True               NaN          Bike     False                      NaN                       NaN                 NaN                 NaN                  NaN                 NaN       7889     1370844000  San Jose, CA, 95126  37.329012 -121.916021                  bike rack                 NaN                     NaN            T13006853                 San Jose  2014-06-14 17:52:49          False
# 4  The bike is a grey, blue, and black Schwinn Ka...             True               NaN          Bike     False                      NaN                       NaN                 NaN                 NaN                  NaN                 NaN       9705     1278741600  Sandusky, OH, 44870  41.440356  -82.768114  car bike rack Reward: $75                 NaN                     NaN           2010004433                 Sandusky  2014-06-14 18:17:08          False
#
#                               sder_formatted_address sder_street_number                sder_route sder_postal_code     sder_neighborhood sder_city         sder_county  sder_state   sder_country  date_stolen_epoch  registration_created_at_epoch  registration_updated_at_epoch  s_rec_created_at_epoch
# 0                                                NaN                NaN                       NaN              NaN                   NaN       NaN                 NaN         NaN            NaN                  0                     1436221621                     1446529014                       0
# 1                                                NaN                NaN                       NaN              NaN                   NaN       NaN                 NaN         NaN            NaN                  0                     1444331930                     1446528870                       0
# 2                                                NaN                NaN                       NaN              NaN                   NaN       NaN                 NaN         NaN            NaN                  0                     1431045025                     1446528775                       0
# 3           1323 Martin Ave, San Jose, CA 95126, USA               1323             Martin Avenue            95126  Shasta-Hanchett Park  San Jose  Santa Clara County  California  United States         1370844000                     1376978400                     1446527474              1402768369
# 4  4614 Venice Heights Blvd, Sandusky, OH 44870, USA               4614  Venice Heights Boulevard            44870                   NaN  Sandusky         Erie County        Ohio  United States         1278741600                     1278828000                     1446527873              1402769828

# %%
df.shape
# Out:
# (59619, 57)

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'id', u'title', u'serial', u'manufacturer_name', u'frame_model', u'year', u'thumb', u'large_img', u'is_stock_img', u'stolen', u'stolen_location', u'date_stolen', u'registration_created_at', u'registration_updated_at', u'url', u'api_url', u'manufacturer_id', u'paint_description', u'name', u'frame_size', u'description', u'rear_tire_narrow', u'front_tire_narrow', u'type_of_cycle', u'test_bike', u'rear_wheel_size_iso_bsd', u'front_wheel_size_iso_bsd', u'handlebar_type_slug',
#        u'frame_material_slug', u'front_gear_type_slug', u'rear_gear_type_slug', u'stolen_id', u's_date_stolen', u's_location', u'latitude', u'longitude', u'theft_description', u'locking_description', u'lock_defeat_description', u'police_report_number', u'police_report_department', u's_rec_created_at', u'create_open311', u'sder_formatted_address', u'sder_street_number', u'sder_route', u'sder_postal_code', u'sder_neighborhood', u'sder_city', u'sder_county', u'sder_state', u'sder_country',
#        u'date_stolen_epoch', u'registration_created_at_epoch', u'registration_updated_at_epoch', u's_rec_created_at_epoch'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Analysis

# %%
# Identifying features that have less than entries

for v in df.columns:
    l=df[v].unique()
    if len(l) <= 30:
        print v, l
# Out:
# is_stock_img [False True]
# stolen [False True]
# rear_tire_narrow [True False]
# front_tire_narrow [nan False True]
# type_of_cycle ['Bike' 'Tricycle' 'Cargo Tricycle (rear storage)'
#  'Cargo Bike (rear storage)' 'Cargo Bike (front storage)' 'Recumbent'
#  'Bike Trailer' 'Cargo Tricycle (front storage)' 'Unicycle' 'Tandem'
#  'Trail behind (half bike)' 'Tall Bike']
# test_bike [False]
# rear_wheel_size_iso_bsd [  nan  559.  622.  507.  584.  406.  630.  305.  540.  571.  635.  599.
#   597.  355.  203.  587.  337.  137.  520.  457.  349.  547.  590.  419.
#   451.  369.]
# front_wheel_size_iso_bsd [  nan  559.  622.  507.  584.  406.  630.  305.  635.  571.  597.  599.
#   355.  203.  520.  587.  337.  137.  457.  349.  547.  590.  419.  451.
#   335.  540.  369.  152.]
# handlebar_type_slug [nan 'flat' 'drop' 'rearward' 'bmx' 'other' 'forward']
# frame_material_slug [nan 'aluminum' 'steel' 'composite' 'titanium' 'organic']
# front_gear_type_slug [nan '3' '2' '1' '3-internal' '2-internal']
# rear_gear_type_slug [nan '7' '8' '7-internal' 'fixed' '10' '9' '11' '1' '8-internal'
#  '2-internal' '3-internal' '5' '6' '12' '3' '11-internal' '1-internal' '2'
#  '5-internal' '6-internal' '4' 'continuously-variable' '9-internal'
#  '10-internal' '4-internal' '12-internal']
# locking_description [nan 'Not locked' 'Cable lock' 'Heavy duty bicycle security chain' 'Other'
#  'U-lock' 'Chain with padlock' 'U-lock and cable' 'Two U-locks']
# lock_defeat_description [nan 'Bike was not locked' 'Lock was cut, and left at the scene.'
#  'Other situation, please describe below.'
#  'Object that bike was locked to was broken, removed, or otherwise compromised.'
#  'Lock is missing, along with the bike.'
#  'Lock was opened, and left unharmed at the scene.']
# create_open311 [nan False]

# %% [markdown]
# From this dataframe, the features that are important are identified using the google spreadsheet and used in the classification model. The features that were available only for stolen data (eg. stolen location, and stolen date etc.) were removed. The next step was to remove the features with redundant information and the features that are too sparse which brought down the total number of features to 12. This data cleansing resulted in 11 categorical variables and 1 quantitative variable (year) in the dataset that will be used for our classification model. There were around 14000 null entries in the year column which was also removed during this process. Hence the dataset has around 45000 rows and 12 columns.  The 'Y' variable in our dataset is stolen for which it is "True" or "1" if the bike was stolen and "False" or "0", if it was not.
#
# The frame size in the dataset was entered in diffent units like size, cm, and inches. All the entries in the frame size standardized to six different categories XXS, XS, S, M, L, XL. The size range for each category was provided below in this section

# %%
# Removing columns which do not hold any useful data
df_clean = df.drop ( ['Unnamed: 0', 'id' , 'title' , 'serial' ,'stolen_id', 
            'thumb', 'large_img', 'is_stock_img' , 'url' , 'api_url',
            's_location', 'latitude', 'longitude', 'name',
            'stolen_location' , 'test_bike' , 'type_of_cycle' ,
            'theft_description', 'locking_description', 'lock_defeat_description', 
            'police_report_number', 'police_report_department',  
            'create_open311', 'sder_formatted_address', 'sder_street_number', 'sder_route', 
            'sder_postal_code', 'sder_neighborhood', 'sder_city', 'sder_county', 'sder_state', 
            'sder_country' ] , axis = 1 )

# %%
# Removing columns with repeated information
df_clean = df_clean.drop ( [ 'registration_created_at_epoch' ,'s_date_stolen',  'registration_updated_at_epoch' ,
            's_rec_created_at', 'date_stolen_epoch', 's_rec_created_at_epoch', 'date_stolen', 
            'registration_created_at', 'registration_updated_at'] , axis = 1 )

# %%
df_clean.shape
# Out:
# (59619, 16)

# %%
# Removing columns with Too sparse data
df_clean = df_clean.drop ( ['frame_model'] , axis = 1 )

# %%
df_clean.shape
# Out:
# (59619, 15)

# %% [markdown]
# ## Exploratory Visualization
#
# Exploring 20 most frequent values in each feature column and visually examining if there is any difference between entries corresponding to stolen bikes and not stolen bikes

# %%
#http://stackoverflow.com/questions/16010869/python-plot-a-bar-using-matplotlib-using-a-dictionary
#http://stackoverflow.com/questions/7197315/5-maximum-values-in-a-python-dictionary
#http://stackoverflow.com/questions/4971269/how-to-pick-a-new-color-for-each-plotted-line-within-a-figure-in-matplotlib

import matplotlib.pyplot as plt
import operator
from matplotlib.pyplot import cm 

""" The plotDictionary function below accepts a dictionary contains count values of keys(D) ,number of keys to be plotted(topN)
,axis(ax) ,color(c) ,name of feature column from which the keys were derived(columnName) ,label rotation (labelRotation) ,order 
in which to plot the keys(sortedKeyList). The topN argument is ignored if sortedKeyList is provided."""

def plotDictionary(D, topN = -1 , ax = None , c = 'g' , columnName = None , labelRotation = 60 , sortedKeyList = None):
    if ax is None:
        fig , (ax) = plt.subplots( nrows = 1 , ncols = 1 ,figsize=(14,5) )

    if sortedKeyList is not None:
        D1 = []
        for key in sortedKeyList :
            if D.has_key(key):
                tmp = D[key]
            else :
                tmp = 0
            D1.append(( key ,tmp ))
        D = D1
    else :
        if topN != -1:
            D = (sorted(D.iteritems(), key=operator.itemgetter(1), reverse=True)[:topN])
 
    ax.bar(range(len(D)), [ item[1] for item in D], align='center' , alpha = 0.2, color = c)
    ax.set_xticks(range(len(D)))
    ax.set_title(columnName)
    ax.set_ylabel('Frequency') 
    ax.set_xticklabels( [ str(item[0]).decode('utf-8')[:20] for item in D] , rotation = labelRotation )
    ax.legend()
    return ax

# %%
# To select top 30 (based on frequency or count) in each feature

for v in df_clean.columns:
    plotDictionary ( 
    dict (  df[v].value_counts()) 
    , topN = 30 
    , ax = None 
    , c = 'g'
    , columnName = v
    , labelRotation = 90)
# Out:
# /home/anusha/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
import matplotlib.patches as mpatches

# to plot stolen and not stolen bikes for each feature in the same graph

def createOverlappingDistributionPlotOfTargetValuesByColumn( df , columnToBePlotted, targetColumnName ,countOfItemsToPlot = -1 , ax = None  ) :
    if  countOfItemsToPlot != -1 :
        sortList = df[columnToBePlotted].value_counts().index.values[:countOfItemsToPlot]
    else :
        sortList = df[columnToBePlotted].value_counts().index.values
# for stolen bikes        
    ax = plotDictionary ( 
        dict (  df.iloc[ np.where(df[targetColumnName] == True)][columnToBePlotted].value_counts()) 
        , topN = countOfItemsToPlot 
        , ax = ax 
        , c = 'red'
        , columnName = "overlay bar-chart : " + columnToBePlotted
        , labelRotation = 90 
        , sortedKeyList = sortList )

# for not stolen bikes
    ax = plotDictionary ( 
        dict (  df.iloc[ np.where(df[targetColumnName] == False)][columnToBePlotted].value_counts()) 
        , topN = countOfItemsToPlot
        , ax = ax 
        , c = 'blue'
        , columnName = "overlay bar-chart : " + columnToBePlotted
        , labelRotation = 90
        , sortedKeyList = sortList )
    
    red_patch = mpatches.Patch(color='red', label='stolen bikes' , alpha = 0.2)
    green_patch = mpatches.Patch(color='blue', label='not stolen bikes' , alpha = 0.2)
    ax.legend(handles=[green_patch , red_patch])

    return ax

# %%
df_clean.isnull().sum()
# Out:
# manufacturer_name               1
# year                        14579
# stolen                          0
# manufacturer_id                 0
# paint_description           51621
# frame_size                  21371
# description                 18005
# rear_tire_narrow                0
# front_tire_narrow           39037
# rear_wheel_size_iso_bsd     39211
# front_wheel_size_iso_bsd    39166
# handlebar_type_slug         45244
# frame_material_slug         42604
# front_gear_type_slug        44084
# rear_gear_type_slug         44523
# dtype: int64

# %% [markdown]
# Upto 60% of values are missing in some of the columns. Since imputing such a large portion of data with most frequent value will
# introduce lot of bias, we decided to treat value=missing as a feature in itself

# %% [markdown]
# The individual columns in the dataset are explored in detail below.

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'manufacturer_id' , 'stolen' , 20 , None)

# %% [markdown]
# It seems certain manufacturers have higher portion of stolen bikes when compared to others

# %%
# The manufacturer id is converted to string type as it is not numerical in nature even though it is 
# represented using numbers
df_clean['manufacturer_id'] = df_clean.manufacturer_id.apply(str)

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'rear_tire_narrow' , 'stolen' , 20 , None)

# %% [markdown]
# Bikes with narrow rear tires seems to have a higher propensity to get stolen

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'front_tire_narrow' , 'stolen' , 20 , None)

# %% [markdown]
# Front tire being narrow does not seem to have the same effect as the back tire being narrow.

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'rear_wheel_size_iso_bsd' , 'stolen' , 20 , None)

# %%
# Converting rear wheel size into a categorical column
df_clean['rear_wheel_size_iso_bsd'] = df_clean.rear_wheel_size_iso_bsd.apply(str)

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'front_wheel_size_iso_bsd' , 'stolen' , 20 , None)

# %%
# Converting front wheel size into a categorical column
df_clean['front_wheel_size_iso_bsd'] = df_clean.front_wheel_size_iso_bsd.apply(str)

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'handlebar_type_slug' , 'stolen' , 20 , None)

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'frame_material_slug' , 'stolen' , 20 , None)

# %% [markdown]
# Bikes with steel as frame material seems to have lesser proportion of stolen bikes

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'front_gear_type_slug' , 'stolen' , 20 , None)

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'rear_gear_type_slug' , 'stolen' , 20 , None)

# %% [markdown]
# Propensity to get stolen seems to peak around rear gear count of 7

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'frame_size' , 'stolen' , 20 , None)

# %% [markdown]
# Frame size columns contain multiple values and needs to be standardized. Some of the values are in inches , some in centimetres
# and some using standard frame size notations like - M(medium), L(large), XL(extra large) etc. A mapping of non-standard values to standard values was created for this purpose.
#
# [Frame size standard](https://docs.google.com/spreadsheets/d/1inXgmCGKqa07CRxW2ZOkmBb883ibVuLSbiv8Zm4zLrE/edit?usp=sharing)

# %%
# Standardizing values of frame_size column

fp = open('frame_size.csv','r')
fp.next()
frameSizeDict = {}
for line in fp:
    tmp =  line.replace('\n','').replace('\r','').split(',')
    frameSizeDict[ tmp[0]] = tmp[1] 
fp.close()

def lookUpFrameDict(key) :
    if pd.isnull(key):
        return ''
    return frameSizeDict[key]

# Applying function to standardize on every value and saving data in a new column
df_clean['frame_size_std'] = df_clean.frame_size.apply(lookUpFrameDict)

# Updating missing values to Unknown
df_clean['frame_size_std'][df_clean.frame_size_std == ''] = 'unknown'
# Out:
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_clean.shape
# Out:
# (59619, 16)

# %%
df_clean.columns
# Out:
# Index([u'manufacturer_name', u'year', u'stolen', u'manufacturer_id', u'paint_description', u'frame_size', u'description', u'rear_tire_narrow', u'front_tire_narrow', u'rear_wheel_size_iso_bsd', u'front_wheel_size_iso_bsd', u'handlebar_type_slug', u'frame_material_slug', u'front_gear_type_slug', u'rear_gear_type_slug', u'frame_size_std'], dtype='object')

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'frame_size_std' , 'stolen' , 20 , None)

# %% [markdown]
# After standardizing values, it seems that there is an information bias in the data. It seems that frame size column is more populated in the records corresponding to stolen bikes than records corresponding to non-stolen bikes.

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'year' , 'stolen' , 20 , None)

# %%
print np.unique(df_clean.year)
# Out:
# [  0.   1.   2. ...,  nan  nan  nan]

# %% [markdown]
# The year column seems to have multiple representations , occassionally using one or two digits using the four year representation. Other occassions the year column outright contains spurious records. The non-standarized value needs to be cleaned up and records with spurious values for year needs to be deleted

# %%
# Cleansing values in year column
rowsToBeDeleted = []

for idx in range(df_clean.shape[0]):
    
    if pd.isnull(df_clean['year'].iloc[idx]) :
        rowsToBeDeleted.append(idx)
        continue
# Some entries had two digit values instead of 4 for year. hence 2000 was added to then if the value was between 0 and 16

    if ( df_clean['year'].iloc[idx] >= 0 and df_clean['year'].iloc[idx] <= 16 )  :
        df_clean['year'].iloc[idx] = 2000 + df_clean['year'].iloc[idx]
        continue
      
    if ( df_clean['year'].iloc[idx] >= 17 and df_clean['year'].iloc[idx] <= 19 ) :
        rowsToBeDeleted.append(idx)
        continue
        
    if ( df_clean['year'].iloc[idx] == 20) :
        df_clean['year'].iloc[idx] = 2000
        continue    
        
    if ( df_clean['year'].iloc[idx] >= 21 and df_clean['year'].iloc[idx] <= 99 ) :
        df_clean['year'].iloc[idx] = 1900 + df_clean['year'].iloc[idx]
        continue 
    
    if ( df_clean['year'].iloc[idx] >= 100 and df_clean['year'].iloc[idx] <= 189 ) :
        rowsToBeDeleted.append(idx)
        continue
        
    if ( df_clean['year'].iloc[idx] >= 190 and df_clean['year'].iloc[idx] <= 200 ) :
        df_clean['year'].iloc[idx] =  df_clean['year'].iloc[idx] * 10
        continue 
        
    if ( df_clean['year'].iloc[idx] >= 201 and df_clean['year'].iloc[idx] <= 1799 ) :
        rowsToBeDeleted.append(idx)
        continue
        
    if ( df_clean['year'].iloc[idx] >= 1800 and df_clean['year'].iloc[idx] <= 2016 ) :
        continue 
    
    if ( df_clean['year'].iloc[idx] >= 18000 and df_clean['year'].iloc[idx] <= 20160 ) :
        df_clean['year'].iloc[idx] =  round( df_clean['year'].iloc[idx] / 10 )
        continue 
        
    rowsToBeDeleted.append(idx)
        
        
print len(rowsToBeDeleted)

df_clean = df_clean.drop(df_clean.index[rowsToBeDeleted])

print df_clean.shape
print np.unique (df_clean['year'])
# Out:
# 14610
# (45009, 16)
# [ 1884.  1885.  1908.  1910.  1920.  1935.  1938.  1940.  1941.  1942.
#   1943.  1948.  1950.  1952.  1953.  1954.  1955.  1956.  1957.  1958.
#   1959.  1960.  1961.  1962.  1963.  1964.  1965.  1966.  1967.  1968.
#   1969.  1970.  1971.  1972.  1973.  1974.  1975.  1976.  1977.  1978.
#   1979.  1980.  1981.  1982.  1983.  1984.  1985.  1986.  1987.  1988.
#   1989.  1990.  1991.  1992.  1993.  1994.  1995.  1996.  1997.  1998.
#   1999.  2000.  2001.  2002.  2003.  2004.  2005.  2006.  2007.  2008.
#   2009.  2010.  2011.  2012.  2013.  2014.  2015.  2016.]
# /home/anusha/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'year' , 'stolen' , 20 , None)

# %% [markdown]
# The bike model year seems to a significant feature in determining the propensity of bikes to be stolen

# %% [markdown]
# Now that, all columns in the dataset are explored and standardized, we shall proceed to convert the categorical variables into indicator columns. We are using DictVectorizer function from sklearn library for this purpose.

# %%
# Since Manufacturer id and manufacturer name has the same information, manufactured id was used in the classification model 
# as the manufacturer name has entries with too sparse data. eg: Manufacturer id 47 corresponds to manufacturer "Trek"
columnsIwant =  df_clean[['manufacturer_id','rear_tire_narrow','front_tire_narrow','rear_wheel_size_iso_bsd','front_wheel_size_iso_bsd','handlebar_type_slug','frame_material_slug','front_gear_type_slug','rear_gear_type_slug','frame_size_std','year','stolen']]

# %%
columnsIwant.shape
# Out:
# (45009, 12)

# %%
# To calculate invalid entries in each feature
columnsIwant.isnull().sum()
# Out:
# manufacturer_id                 0
# rear_tire_narrow                0
# front_tire_narrow           27847
# rear_wheel_size_iso_bsd         0
# front_wheel_size_iso_bsd        0
# handlebar_type_slug         33596
# frame_material_slug         30937
# front_gear_type_slug        32486
# rear_gear_type_slug         32743
# frame_size_std                  0
# year                            0
# stolen                          0
# dtype: int64

# %%
# Replace NULLs and Blanks with string missing

def checkMissing(x) :
    if ( pd.isnull(x) or str(x).strip() == ''):
        return 'missing'
    else :
        return x
        
for k in columnsIwant.columns :
    columnsIwant[k] = columnsIwant[k].apply(checkMissing)

columnsIwant.isnull().sum()
# Out:
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# manufacturer_id             0
# rear_tire_narrow            0
# front_tire_narrow           0
# rear_wheel_size_iso_bsd     0
# front_wheel_size_iso_bsd    0
# handlebar_type_slug         0
# frame_material_slug         0
# front_gear_type_slug        0
# rear_gear_type_slug         0
# frame_size_std              0
# year                        0
# stolen                      0
# dtype: int64

# %%
tempDictionary = columnsIwant.apply(dict , axis = 1)

# %%
from sklearn.feature_extraction import DictVectorizer
vec = DictVectorizer()

bikeAttributesDataAll = vec.fit_transform(tempDictionary).toarray()
allColumns = vec.get_feature_names()
print len(allColumns)


# Drop sparsely populated columns from Bike Attributes Data      

x = sum(bikeAttributesDataAll)
selectedColumns = []
selectedColumnsIdx = []

for i in range(len(x)) :
    if x[i] > -1 :
        selectedColumns.append(allColumns[i])
        selectedColumnsIdx.append(i)
        
print len(selectedColumns)
print selectedColumns

bikeAttributesDataSelectedColumns = [ x[selectedColumnsIdx]   for x in bikeAttributesDataAll]
# Out:
# 726
# 726
# ['frame_material_slug=aluminum', 'frame_material_slug=composite', 'frame_material_slug=missing', 'frame_material_slug=organic', 'frame_material_slug=steel', 'frame_material_slug=titanium', 'frame_size_std=L', 'frame_size_std=M', 'frame_size_std=S', 'frame_size_std=XL', 'frame_size_std=XS', 'frame_size_std=XXS', 'frame_size_std=unknown', 'front_gear_type_slug=1', 'front_gear_type_slug=2', 'front_gear_type_slug=2-internal', 'front_gear_type_slug=3', 'front_gear_type_slug=3-internal', 'front_gear_type_slug=missing', 'front_tire_narrow', 'front_tire_narrow=missing', 'front_wheel_size_iso_bsd=152.0', 'front_wheel_size_iso_bsd=203.0', 'front_wheel_size_iso_bsd=305.0', 'front_wheel_size_iso_bsd=335.0', 'front_wheel_size_iso_bsd=337.0', 'front_wheel_size_iso_bsd=349.0', 'front_wheel_size_iso_bsd=355.0', 'front_wheel_size_iso_bsd=369.0', 'front_wheel_size_iso_bsd=406.0', 'front_wheel_size_iso_bsd=419.0', 'front_wheel_size_iso_bsd=451.0', 'front_wheel_size_iso_bsd=457.0', 'front_wheel_size_iso_bsd=507.0', 'front_wheel_size_iso_bsd=520.0', 'front_wheel_size_iso_bsd=540.0', 'front_wheel_size_iso_bsd=547.0', 'front_wheel_size_iso_bsd=559.0', 'front_wheel_size_iso_bsd=571.0', 'front_wheel_size_iso_bsd=584.0', 'front_wheel_size_iso_bsd=587.0', 'front_wheel_size_iso_bsd=590.0', 'front_wheel_size_iso_bsd=597.0', 'front_wheel_size_iso_bsd=599.0', 'front_wheel_size_iso_bsd=622.0', 'front_wheel_size_iso_bsd=630.0', 'front_wheel_size_iso_bsd=635.0', 'front_wheel_size_iso_bsd=nan', 'handlebar_type_slug=bmx', 'handlebar_type_slug=drop', 'handlebar_type_slug=flat', 'handlebar_type_slug=forward', 'handlebar_type_slug=missing', 'handlebar_type_slug=other', 'handlebar_type_slug=rearward', 'manufacturer_id=1', 'manufacturer_id=100', 'manufacturer_id=1000', 'manufacturer_id=1001', 'manufacturer_id=1003', 'manufacturer_id=1006', 'manufacturer_id=1007', 'manufacturer_id=1008', 'manufacturer_id=1009', 'manufacturer_id=101', 'manufacturer_id=1011', 'manufacturer_id=1012', 'manufacturer_id=1013', 'manufacturer_id=1015', 'manufacturer_id=1016', 'manufacturer_id=1017', 'manufacturer_id=1019', 'manufacturer_id=102', 'manufacturer_id=1020', 'manufacturer_id=1021', 'manufacturer_id=1022', 'manufacturer_id=1023', 'manufacturer_id=1024', 'manufacturer_id=1025', 'manufacturer_id=1026', 'manufacturer_id=1027', 'manufacturer_id=1028', 'manufacturer_id=1029', 'manufacturer_id=1031', 'manufacturer_id=1032', 'manufacturer_id=1033', 'manufacturer_id=1034', 'manufacturer_id=1035', 'manufacturer_id=1036', 'manufacturer_id=1038', 'manufacturer_id=1039', 'manufacturer_id=104', 'manufacturer_id=1041', 'manufacturer_id=1042', 'manufacturer_id=1043', 'manufacturer_id=1044', 'manufacturer_id=1045', 'manufacturer_id=1046', 'manufacturer_id=1048', 'manufacturer_id=1049', 'manufacturer_id=105', 'manufacturer_id=1050', 'manufacturer_id=1051', 'manufacturer_id=1053', 'manufacturer_id=1055', 'manufacturer_id=1056', 'manufacturer_id=1057', 'manufacturer_id=1058', 'manufacturer_id=1059', 'manufacturer_id=1060', 'manufacturer_id=1061', 'manufacturer_id=1062', 'manufacturer_id=1063', 'manufacturer_id=1064', 'manufacturer_id=1065', 'manufacturer_id=1066', 'manufacturer_id=1067', 'manufacturer_id=1068', 'manufacturer_id=1069', 'manufacturer_id=1070', 'manufacturer_id=1071', 'manufacturer_id=1072', 'manufacturer_id=1073', 'manufacturer_id=1074', 'manufacturer_id=1075', 'manufacturer_id=1077', 'manufacturer_id=1078', 'manufacturer_id=1079', 'manufacturer_id=1080', 'manufacturer_id=1081', 'manufacturer_id=1082', 'manufacturer_id=1083', 'manufacturer_id=1087', 'manufacturer_id=1088', 'manufacturer_id=1089', 'manufacturer_id=109', 'manufacturer_id=1090', 'manufacturer_id=1091', 'manufacturer_id=1092', 'manufacturer_id=1093', 'manufacturer_id=1094', 'manufacturer_id=1095', 'manufacturer_id=1096', 'manufacturer_id=1097', 'manufacturer_id=1098', 'manufacturer_id=1099', 'manufacturer_id=11', 'manufacturer_id=1100', 'manufacturer_id=1101', 'manufacturer_id=1102', 'manufacturer_id=1103', 'manufacturer_id ...

# %%
# Columns count
print len( bikeAttributesDataAll[0] )
print "The total number of columns: ", len ( bikeAttributesDataSelectedColumns[0])
# Out:
# 726
# The total number of columns:  726

# %%
# Rows Count
print len( bikeAttributesDataAll )
print "The total number of rows: ", len ( bikeAttributesDataSelectedColumns)
# Out:
# 45009
# The total number of rows:  45009

# %% [markdown]
# ##Text features analysis
#
# Bike description and paint description are the verbatims available in the dataset.  After reading through some of the descriptions, it became evident that there is clear information bias in the dataset. The bias details are illustrated below

# %%
# Extracting length of description columns
def getLength(x):
    return len(str(x))

df_clean['description_len'] = df_clean.description.apply(getLength)
df_clean['paint_description_len'] = df_clean.paint_description.apply(getLength)

df_clean['description_is_missing'] = df_clean.description.apply(pd.isnull)
df_clean['paint_description_is_missing'] = df_clean.paint_description.apply(pd.isnull)

# %%
fig, ax = plt.subplots(figsize=(8,8))
colorDict = { True : "r", False :"b"}
for label, df in df_clean['description_len'].groupby(df_clean["stolen"]):
    df.plot(kind="kde", ax=ax, label=label , color = colorDict[label] )
    ax.set_xlim([1 , 300])
plt.legend(["Not stolen" , "Stolen"])
plt.title("Length of Bike Description text - Stolen vs non-Stolen bikes\n")
plt.xlabel("Length of Bike Description text")

# %% [markdown]
# It can be seen that people who got their bikes stolen tend to write lengthier description of the bikes. This is because they take extra effort to a vivid description to make sure that when someone who has read the description happens to see that bike, he/she is able to identify it. The people who are merely registering their bikes with site, but are in possession of their bikes probably are less inclined in writing a very detailed description of their bikes.
#
# Due to heavy information bias of the column & sparse nature of features obtained out of this column, we decided to leave out this column from the remainder of the analysis

# %% [markdown]
# Next we proceed to investigate the paint description verbatims.

# %%
fig, ax = plt.subplots(figsize=(8,8))
colorDict = { True : "r", False :"b"}
for label, df in df_clean['paint_description_len'].groupby(df_clean["stolen"]):
    df.plot(kind="kde", ax=ax, label=label , color = colorDict[label] )
    ax.set_xlim([1 , 25])
plt.legend(["Not stolen" , "Stolen"])

# %% [markdown]
# The paint description column has lesser information bias than the description column as seen in the above chart.

# %% [markdown]
# Next, we can use standard text processing methods to extract some features out of verbatims of paint descriptions. The following function strips punctuations and special characters from the descriptions, converts the words in the verbatims to lemmas and does filtering on the lemma to keep only the adjectives & the nouns.

# %%
from pattern.en import parse
from pattern.en import pprint
from pattern.vector import stem, PORTER, LEMMA
punctuation = list('.,;:!?()[]{}`''\/"@#$^&*+-|=~_')

from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS

from nltk.stem.wordnet import WordNetLemmatizer
import nltk
#nltk.download()
lmtzr = WordNetLemmatizer()

import re
import math
regex1=re.compile(r"\.{2,}")
regex2=re.compile(r"\-{2,}")

def get_keywords(thetext):
    if pd.isnull(thetext) :
        return ''
    thetext=re.sub(regex1, ' ', thetext)
    thetext=re.sub(regex2, ' ', thetext)
    keywords=[]
    for i,sentence in enumerate(parse(thetext, tokenize=True, lemmata=True).split()):
        for token in sentence:
            if len(token[4]) >0:
                if token[1] in ['JJ', 'JJR', 'JJS', 'NN', 'NNS','NNP','NNPS']:
                    if (token[4] in stopwords or 
                        token[4][0] in punctuation or 
                        token[4][-1] in punctuation or 
                        len(token[4])== 1):
                        
                        continue
                        
                    tmp = token[4:]
                    # Using a second library for additional lemmatization
                    for i in range(len(tmp)) :
                        tmp[i] = lmtzr.lemmatize(tmp[i])
                    keywords.append( ' '.join(tmp))
    keywordString = ' '.join(keywords)
    return keywordString

print get_keywords("Tan With Light Blue Logo And Stripes")
print get_keywords("Blk/Char/Red")
# Out:
# tan light blue logo stripe
# blk char red

# %% [markdown]
# The function is then applied on to paint description columns and the result stored in new column

# %%
df_clean['paint_description_kw'] = df_clean.paint_description.apply(get_keywords)

# %% [markdown]
# Next we use CountVectorizer function from sklearn to transform the verbatims into features. We set a threshold on document frequency to be atleast 50 for a keyword to be treated as a feature input to the model.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=50) ## Minimum document frequency - 50
corpus = df_clean['paint_description_kw'].values

X = vectorizer.fit_transform(corpus)
paintDescKeyWordFeatures = vectorizer.get_feature_names()
print paintDescKeyWordFeatures
paintDescFeaturesData = X.toarray()

# Row Count
print len(paintDescFeaturesData)

# Column count
print len(paintDescFeaturesData[0])
# Out:
# [u'accent', u'black', u'blk', u'blue', u'bright', u'carbon', u'celeste', u'charcoal', u'chrome', u'clear', u'coat', u'color', u'cream', u'crystal', u'cyan', u'dark', u'decal', u'flat', u'fork', u'frame', u'gloss', u'glossy', u'gold', u'gray', u'green', u'grey', u'highlight', u'letter', u'lettering', u'light', u'logo', u'maroon', u'matt', u'matte', u'metallic', u'neon', u'orange', u'paint', u'pearl', u'pink', u'purple', u'red', u'satin', u'seat', u'silver', u'sticker', u'stripe', u'teal', u'trek', u'trim', u'tube', u'white', u'wht', u'yellow']
# 45009
# 54

# %%
# Following cleansing steps have to be taken and the features calculated again.
# merge black and blk
# merge white and wht
# merge matte and matt
# merge letter and lettering
# merge gray and grey
# ignore the following words as they are too generic - color,flat,fork,frame,highlight,satin,sticker,trek,trim,tube

def cleanKeyWords(paintDesc):
    return paintDesc.replace('blk','black').replace('wht','white').replace('matte','matt').replace('lettering','letter').replace('gray','grey').replace('glossy','gloss')

df_clean['paint_description_kw'] = df_clean.paint_description_kw.apply(cleanKeyWords)

# Re-running count vectorizer after determining words to be ignored from the paint description
ignore_words = ['color' , 'flat' , 'fork' , 'frame' , 'highlight' , 'satin' , 'sticker', 'trek' , 'trim' , 'tube']


vectorizer = CountVectorizer(min_df=50,stop_words = ignore_words) 

X = vectorizer.fit_transform(corpus)
paintDescKeyWordFeatures = vectorizer.get_feature_names()
print paintDescKeyWordFeatures
paintDescFeaturesData = X.toarray()

# Row Count
print len(paintDescFeaturesData)

# Column count
print "The number of features from paint description: ", len(paintDescFeaturesData[0])

#colorsIwant = [u'accent', u'black', u'blk', u'blue', u'bright', u'carbon', u'charcoal', u'chrome', u'clear', u'coat', u'cream', u'crystal', u'cyan', u'dark', u'decal', u'flat', u'fork', u'gloss', u'glossy', u'gold', u'gray', u'green', u'grey', u'letter', u'lettering', u'light', u'logo', u'maroon', u'matte', u'metallic', u'neon', u'orange', u'pearl', u'pink', u'purple', u'red', u'silver', u'stripe', u'teal', u'trim', u'white', u'wht', u'yellow']
# Out:
# [u'accent', u'black', u'blue', u'bright', u'carbon', u'celeste', u'charcoal', u'chrome', u'clear', u'coat', u'cream', u'crystal', u'cyan', u'dark', u'decal', u'gloss', u'gold', u'green', u'grey', u'letter', u'light', u'logo', u'maroon', u'matt', u'metallic', u'neon', u'orange', u'paint', u'pearl', u'pink', u'purple', u'red', u'seat', u'silver', u'stripe', u'teal', u'white', u'yellow']
# 45009
# The number of features from paint description:  38

# %% [markdown]
# At the point we completed investigating the entire dataset and have created bike attributes features and text features separately. We now proceed to merge both kinds of features

# %%
finalData = np.concatenate((bikeAttributesDataSelectedColumns, paintDescFeaturesData), axis=1)
finalColumns =  selectedColumns + paintDescKeyWordFeatures
print "The final number of rows used in the classification: ", len(finalData) # Rows Count
print "The final number of columns used in the classification: ",len(finalData[0]) # Columns Count
# Out:
# The final number of rows used in the classification:  45009
# The final number of columns used in the classification:  764

# %%
# Creating a list of features
features = []
for x in finalColumns :
    if x != 'stolen' :
        features.append(x)

# %%
# Converting the features + target array into a dataframe
finalDataDF = pd.DataFrame( finalData , columns = finalColumns)

# %%
# Checking target column value counts to establish base line accuracy
finalDataDF.stolen.value_counts()
# Out:
# 1    27125
# 0    17884
# Name: stolen, dtype: int64

# %% [markdown]
#  The baseline accuracy score is thus calculated as ( 27125/(27125+17884)) = 0.60

# %% [markdown]
# Next we try and improve the baseline classification accuracy score by deploying classifiers. Towards this we first compute the train and test portions of the dataset.

# %%
# Creating a mask column to separate train and test records

from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix

itrain, itest = train_test_split(xrange(finalDataDF.shape[0]), train_size=0.7)
mask=np.ones(finalDataDF.shape[0], dtype='int')
mask[itrain]=1
mask[itest]=0
mask = (mask==1)

# %% [markdown]
# The following generic functions are used to assist in the model build

# %%
def cv_optimize(clf, parameters, X, y, n_jobs=1, n_folds=5, score_func=None):
    if score_func:
        gs = GridSearchCV(clf, param_grid=parameters, cv=n_folds, n_jobs=n_jobs, scoring=score_func)
    else:
        gs = GridSearchCV(clf, param_grid=parameters, n_jobs=n_jobs, cv=n_folds)
    gs.fit(X, y)
    print "BEST", gs.best_params_, gs.best_score_, gs.grid_scores_
    best = gs.best_estimator_
    return best


def do_classify(clf, parameters, indf, featurenames, targetname, target1val, mask=None, reuse_split=None, score_func=None, n_folds=5, n_jobs=1):
    subdf=indf[featurenames]
    X=subdf.values
    y=(indf[targetname].values==target1val)*1
    if mask !=None:
        print "using mask"
        Xtrain, Xtest, ytrain, ytest = X[mask], X[~mask], y[mask], y[~mask]
    if reuse_split !=None:
        print "using reuse split"
        Xtrain, Xtest, ytrain, ytest = reuse_split['Xtrain'], reuse_split['Xtest'], reuse_split['ytrain'], reuse_split['ytest']
    if parameters:
        clf = cv_optimize(clf, parameters, Xtrain, ytrain, n_jobs=n_jobs, n_folds=n_folds, score_func=score_func)
    clf=clf.fit(Xtrain, ytrain)
    training_accuracy = clf.score(Xtrain, ytrain)
    test_accuracy = clf.score(Xtest, ytest)
    print "############# based on standard predict ################"
    print "Accuracy on training data: %0.2f" % (training_accuracy)
    print "Accuracy on test data:     %0.2f" % (test_accuracy)
    print confusion_matrix(ytest, clf.predict(Xtest))
    print "########################################################"
    return clf, Xtrain, ytrain, Xtest, ytest

from sklearn.metrics import roc_curve, auc
def make_roc(name, clf, ytest, xtest, ax=None, labe=5, proba=True, skip=0):
    initial=False
    if not ax:
        ax=plt.gca()
        initial=True
    if proba:#for stuff like logistic regression
        fpr, tpr, thresholds=roc_curve(ytest, clf.predict_proba(xtest)[:,1])
    else:#for stuff like SVM
        fpr, tpr, thresholds=roc_curve(ytest, clf.decision_function(xtest))
    roc_auc = auc(fpr, tpr)
    if skip:
        l=fpr.shape[0]
        ax.plot(fpr[0:l:skip], tpr[0:l:skip], '.-', alpha=0.3, label='ROC curve for %s (area = %0.2f)' % (name, roc_auc))
    else:
        ax.plot(fpr, tpr, '.-', alpha=0.3, label='ROC curve for %s (area = %0.2f)' % (name, roc_auc))
    label_kwargs = {}
    label_kwargs['bbox'] = dict(
        boxstyle='round,pad=0.3', alpha=0.2,
    )
    if labe!=None:
        for k in xrange(0, fpr.shape[0],labe):
            #from https://gist.github.com/podshumok/c1d1c9394335d86255b8
            threshold = str(np.round(thresholds[k], 2))
            ax.annotate(threshold, (fpr[k], tpr[k]), **label_kwargs)
    if initial:
        ax.plot([0, 1], [0, 1], 'k--')
        ax.set_xlim([0.0, 1.0])
        ax.set_ylim([0.0, 1.05])
        ax.set_xlabel('False Positive Rate')
        ax.set_ylabel('True Positive Rate')
        ax.set_title('ROC')
    ax.legend(loc="lower right")
    return ax

# %% [markdown]
# Since our dataset has lots of indicator variables, decision tree and random forest are our intial choice for classifiers. These classifiers were trained by 70% of the dataset and the probability of each bike in the test set getting stolen was predicted. Random forests is known to handle high dimensional datasets well. Another approach we take is using Principal component analysis for dimensionality reduction and using Support vector machines and Logistic regression on the reduced datasets.
#
# Random Forests also allows to determine the important features in predicting Y through a function feature_importances, it can be used for efficient visulaization.

# %%
# Doing parameter search on a Decision tree classifier with Gini criterion

from sklearn.tree import DecisionTreeClassifier
clfdt=DecisionTreeClassifier()
parameters = {"max_depth": range(1,10,1)}
clfdt, Xtrain, ytrain, Xtest, ytest  = do_classify(clfdt, parameters, finalDataDF, features, 'stolen', 1, mask=mask)
# Out:
# using mask
# BEST {'max_depth': 7} 0.789468672634 [mean: 0.74856, std: 0.03811, params: {'max_depth': 1}, mean: 0.77906, std: 0.06893, params: {'max_depth': 2}, mean: 0.74691, std: 0.02991, params: {'max_depth': 3}, mean: 0.77052, std: 0.03574, params: {'max_depth': 4}, mean: 0.78071, std: 0.04799, params: {'max_depth': 5}, mean: 0.78706, std: 0.05375, params: {'max_depth': 6}, mean: 0.78947, std: 0.05816, params: {'max_depth': 7}, mean: 0.78937, std: 0.05438, params: {'max_depth': 8}, mean: 0.78626, std: 0.05601, params: {'max_depth': 9}]
# ############# based on standard predict ################
# Accuracy on training data: 0.81
# Accuracy on test data:     0.80
# [[4395 1003]
#  [1640 6465]]
# ########################################################
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.

# %%
# Creating a classification report for this decision tree.

from sklearn.metrics import classification_report
print classification_report(ytest,clfdt.predict(Xtest))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.73      0.81      0.77      5398
#           1       0.87      0.80      0.83      8105
#
# avg / total       0.81      0.80      0.81     13503

# %%
# Changing split criterion to entropy and re-running the decision tree

clfdt_entropy = DecisionTreeClassifier()
parameters = {"criterion": ['entropy'],  "max_depth": range(1,10,1)}
clfdt_entropy, Xtrain, ytrain, Xtest, ytest  = do_classify(clfdt_entropy, parameters, finalDataDF, features, 'stolen', 1, mask=mask)
# Out:
# using mask
# BEST {'criterion': 'entropy', 'max_depth': 6} 0.790706532089 [mean: 0.74856, std: 0.03811, params: {'criterion': 'entropy', 'max_depth': 1}, mean: 0.77906, std: 0.06893, params: {'criterion': 'entropy', 'max_depth': 2}, mean: 0.76284, std: 0.04887, params: {'criterion': 'entropy', 'max_depth': 3}, mean: 0.75716, std: 0.03532, params: {'criterion': 'entropy', 'max_depth': 4}, mean: 0.77068, std: 0.03908, params: {'criterion': 'entropy', 'max_depth': 5}, mean: 0.79071, std: 0.05632, params: {'criterion': 'entropy', 'max_depth': 6}, mean: 0.78277, std: 0.04923, params: {'criterion': 'entropy', 'max_depth': 7}, mean: 0.78896, std: 0.05842, params: {'criterion': 'entropy', 'max_depth': 8}, mean: 0.78626, std: 0.05188, params: {'criterion': 'entropy', 'max_depth': 9}]
# ############# based on standard predict ################
# Accuracy on training data: 0.81
# Accuracy on test data:     0.80
# [[4419  979]
#  [1689 6416]]
# ########################################################
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.

# %%
# Creating a classification report for this decision tree.

from sklearn.metrics import classification_report
print classification_report(ytest,clfdt_entropy.predict(Xtest))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.72      0.82      0.77      5398
#           1       0.87      0.79      0.83      8105
#
# avg / total       0.81      0.80      0.80     13503

# %% [markdown]
# We get similar performance metrics for both Gini and Entropy split criterion.

# %% [markdown]
# The decision tree seems to be doing a good job of identifying the stolen bikes as shown by high precision score. The F1 score which is considered as a trade-off of precision and recall is also higher for the stolen bikes.

# %% [markdown]
# The best fit decision tree has too many nodes to interpret visually. In order to visually examine and interpret the interplay of key factors only, a under-fitted decision tree with 15 nodes only was created.

# %%
# Building a decision tree after setting cap on leaf nodes at 15

clfdt_short=DecisionTreeClassifier()

parameters = {"max_leaf_nodes": [15]}
clfdt_short, Xtrain, ytrain, Xtest, ytest  = do_classify(clfdt_short, parameters, finalDataDF, features, 'stolen', 1, mask=mask)

# Exporting tree to GraphViz DOT formant
from sklearn import tree
tree.export_graphviz(clfdt_short, out_file= "tree.dot", feature_names=features)

# Using GraphViz DOT tool to convert tree to .PNG format
import os
out = os.system("dot -Tpng tree.dot -o tree_short.png")
# Out:
# using mask
# BEST {'max_leaf_nodes': 15} 0.775280898876 [mean: 0.77528, std: 0.04670, params: {'max_leaf_nodes': 15}]
# ############# based on standard predict ################
# Accuracy on training data: 0.80
# Accuracy on test data:     0.80
# [[4732  666]
#  [2081 6024]]
# ########################################################
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.

# %% [markdown]
# As expected , this tree underfits the data. We proceed to create a tree diagram.

# %%
# Displaying decision tree from the prior step
from IPython.display import Image
Image(filename='tree_short.png')

# %% [markdown]
# Next we evaluated the performance of RandomForestClassifier on the same dataset

# %%
# Training a random forest classifier ; Coarse search on parameter - number of estimators

from sklearn.ensemble import RandomForestClassifier
clfForest = RandomForestClassifier()
parameters = {"n_estimators": range(1, 101, 5)}
clfForest, Xtrain, ytrain, Xtest, ytest = do_classify(clfForest, parameters, 
                                                       finalDataDF, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'n_estimators': 71} 0.786548593919 [mean: 0.75259, std: 0.04091, params: {'n_estimators': 1}, mean: 0.77696, std: 0.05373, params: {'n_estimators': 6}, mean: 0.77680, std: 0.04773, params: {'n_estimators': 11}, mean: 0.78122, std: 0.05199, params: {'n_estimators': 16}, mean: 0.78134, std: 0.04817, params: {'n_estimators': 21}, mean: 0.78299, std: 0.05151, params: {'n_estimators': 26}, mean: 0.78350, std: 0.04930, params: {'n_estimators': 31}, mean: 0.78569, std: 0.05023, params: {'n_estimators': 36}, mean: 0.78442, std: 0.04879, params: {'n_estimators': 41}, mean: 0.78509, std: 0.05165, params: {'n_estimators': 46}, mean: 0.78518, std: 0.04997, params: {'n_estimators': 51}, mean: 0.78509, std: 0.05087, params: {'n_estimators': 56}, mean: 0.78531, std: 0.04862, params: {'n_estimators': 61}, mean: 0.78503, std: 0.05006, params: {'n_estimators': 66}, mean: 0.78655, std: 0.04940, params: {'n_estimators': 71}, mean: 0.78547, std: 0.05045, params: {'n_estimators': 76}, mean: 0.78636, std: 0.05021, params: {'n_estimators': 81}, mean: 0.78598, std: 0.05038, params: {'n_estimators': 86}, mean: 0.78610, std: 0.04978, params: {'n_estimators': 91}, mean: 0.78582, std: 0.05004, params: {'n_estimators': 96}]
# ############# based on standard predict ################
# Accuracy on training data: 0.96
# Accuracy on test data:     0.81
# [[4368 1030]
#  [1579 6526]]
# ########################################################

# %%
best_estimator_count = clfForest.get_params()['n_estimators']
print best_estimator_count
# Out:
# 71

# %%
print classification_report(ytest,clfForest.predict(Xtest))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.73      0.81      0.77      5398
#           1       0.86      0.81      0.83      8105
#
# avg / total       0.81      0.81      0.81     13503

# %% [markdown]
# The model from coarse search on number of estimators parameter already seems to be doing a notch better than decision tree. Next we optimize the Random Forest for max_depth

# %%
# Continuing coarse search after additon of max_depth parameter to the search

parameters = {"n_estimators": range(best_estimator_count -6, best_estimator_count+7, 3) , "max_depth" : range ( 1, 49 , 5)}
clfForest, Xtrain, ytrain, Xtest, ytest = do_classify(clfForest, parameters, 
                                                       finalDataDF, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'n_estimators': 68, 'max_depth': 31} 0.79486447026 [mean: 0.60506, std: 0.00081, params: {'n_estimators': 65, 'max_depth': 1}, mean: 0.60477, std: 0.00093, params: {'n_estimators': 68, 'max_depth': 1}, mean: 0.60474, std: 0.00102, params: {'n_estimators': 71, 'max_depth': 1}, mean: 0.60604, std: 0.00254, params: {'n_estimators': 74, 'max_depth': 1}, mean: 0.60604, std: 0.00271, params: {'n_estimators': 77, 'max_depth': 1}, mean: 0.69523, std: 0.05353, params: {'n_estimators': 65, 'max_depth': 6}, mean: 0.69511, std: 0.05390, params: {'n_estimators': 68, 'max_depth': 6}, mean: 0.69438, std: 0.05349, params: {'n_estimators': 71, 'max_depth': 6}, mean: 0.69365, std: 0.05413, params: {'n_estimators': 74, 'max_depth': 6}, mean: 0.69393, std: 0.05313, params: {'n_estimators': 77, 'max_depth': 6}, mean: 0.74567, std: 0.05807, params: {'n_estimators': 65, 'max_depth': 11}, mean: 0.73494, std: 0.07310, params: {'n_estimators': 68, 'max_depth': 11}, mean: 0.73919, std: 0.07532, params: {'n_estimators': 71, 'max_depth': 11}, mean: 0.73456, std: 0.07513, params: {'n_estimators': 74, 'max_depth': 11}, mean: 0.73599, std: 0.07106, params: {'n_estimators': 77, 'max_depth': 11}, mean: 0.77500, std: 0.05686, params: {'n_estimators': 65, 'max_depth': 16}, mean: 0.77268, std: 0.05397, params: {'n_estimators': 68, 'max_depth': 16}, mean: 0.75973, std: 0.07140, params: {'n_estimators': 71, 'max_depth': 16}, mean: 0.75868, std: 0.07239, params: {'n_estimators': 74, 'max_depth': 16}, mean: 0.76322, std: 0.07287, params: {'n_estimators': 77, 'max_depth': 16}, mean: 0.78756, std: 0.05058, params: {'n_estimators': 65, 'max_depth': 21}, mean: 0.78887, std: 0.05133, params: {'n_estimators': 68, 'max_depth': 21}, mean: 0.79099, std: 0.05268, params: {'n_estimators': 71, 'max_depth': 21}, mean: 0.78921, std: 0.05126, params: {'n_estimators': 74, 'max_depth': 21}, mean: 0.78887, std: 0.05069, params: {'n_estimators': 77, 'max_depth': 21}, mean: 0.79080, std: 0.05299, params: {'n_estimators': 65, 'max_depth': 26}, mean: 0.79236, std: 0.05311, params: {'n_estimators': 68, 'max_depth': 26}, mean: 0.79439, std: 0.05546, params: {'n_estimators': 71, 'max_depth': 26}, mean: 0.79423, std: 0.05498, params: {'n_estimators': 74, 'max_depth': 26}, mean: 0.79385, std: 0.05425, params: {'n_estimators': 77, 'max_depth': 26}, mean: 0.79267, std: 0.05447, params: {'n_estimators': 65, 'max_depth': 31}, mean: 0.79486, std: 0.05381, params: {'n_estimators': 68, 'max_depth': 31}, mean: 0.79423, std: 0.05441, params: {'n_estimators': 71, 'max_depth': 31}, mean: 0.79483, std: 0.05424, params: {'n_estimators': 74, 'max_depth': 31}, mean: 0.79385, std: 0.05425, params: {'n_estimators': 77, 'max_depth': 31}, mean: 0.79394, std: 0.05452, params: {'n_estimators': 65, 'max_depth': 36}, mean: 0.79423, std: 0.05171, params: {'n_estimators': 68, 'max_depth': 36}, mean: 0.79347, std: 0.05301, params: {'n_estimators': 71, 'max_depth': 36}, mean: 0.79328, std: 0.05302, params: {'n_estimators': 74, 'max_depth': 36}, mean: 0.79369, std: 0.05112, params: {'n_estimators': 77, 'max_depth': 36}, mean: 0.79160, std: 0.05157, params: {'n_estimators': 65, 'max_depth': 41}, mean: 0.79191, std: 0.05166, params: {'n_estimators': 68, 'max_depth': 41}, mean: 0.79379, std: 0.05205, params: {'n_estimators': 71, 'max_depth': 41}, mean: 0.79350, std: 0.05187, params: {'n_estimators': 74, 'max_depth': 41}, mean: 0.79325, std: 0.05108, params: {'n_estimators': 77, 'max_depth': 41}, mean: 0.79172, std: 0.05079, params: {'n_estimators': 65, 'max_depth': 46}, mean: 0.79191, std: 0.05184, params: {'n_estimators': 68, 'max_depth': 46}, mean: 0.79115, std: 0.05075, params: {'n_estimators': 71, 'max_depth': 46}, mean: 0.79080, std: 0.05337, params: {'n_estimators': 74, 'max_depth': 46}, mean: 0.79233, std: 0.05106, params: {'n_estimators': 77, 'max_depth': 46}]
# ############# based on standard predict ################
# Accuracy on training data: 0.92
# Accuracy on test data:     0.81
# [[4428  970]
#  [1581 6524]]
# ########################################################

# %%
best_estimator_count = clfForest.get_params()['n_estimators']
best_max_depth = clfForest.get_params()['max_depth']

print best_estimator_count , best_max_depth
# Out:
# 68 31

# %%
print classification_report(ytest,clfForest.predict(Xtest))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.74      0.82      0.78      5398
#           1       0.87      0.80      0.84      8105
#
# avg / total       0.82      0.81      0.81     13503

# %% [markdown]
# Analysis of this report

# %%
# Continuing coarse search after addition of min_samples_split parameter

parameters = {"n_estimators":  range(best_estimator_count-4, best_estimator_count+4, 3) , 
              "max_depth" : range(best_max_depth-4, best_max_depth+4, 3) ,
              "min_samples_split": range(2,100,5)}
clfForest, Xtrain, ytrain, Xtest, ytest = do_classify(clfForest, parameters, 
                                                       finalDataDF, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'min_samples_split': 7, 'n_estimators': 64, 'max_depth': 30} 0.797086269282 [mean: 0.79109, std: 0.05354, params: {'min_samples_split': 2, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79153, std: 0.05401, params: {'min_samples_split': 2, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79156, std: 0.05419, params: {'min_samples_split': 2, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79220, std: 0.05403, params: {'min_samples_split': 7, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79296, std: 0.05411, params: {'min_samples_split': 7, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79236, std: 0.05374, params: {'min_samples_split': 7, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79102, std: 0.05442, params: {'min_samples_split': 12, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79169, std: 0.05467, params: {'min_samples_split': 12, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79248, std: 0.05535, params: {'min_samples_split': 12, 'n_estimators': 70, 'max_depth': 27}, mean: 0.78979, std: 0.05602, params: {'min_samples_split': 17, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79014, std: 0.05627, params: {'min_samples_split': 17, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79099, std: 0.05640, params: {'min_samples_split': 17, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79413, std: 0.05712, params: {'min_samples_split': 22, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79442, std: 0.05652, params: {'min_samples_split': 22, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79429, std: 0.05724, params: {'min_samples_split': 22, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79379, std: 0.05552, params: {'min_samples_split': 27, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79410, std: 0.05622, params: {'min_samples_split': 27, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79407, std: 0.05660, params: {'min_samples_split': 27, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79036, std: 0.05606, params: {'min_samples_split': 32, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79106, std: 0.05704, params: {'min_samples_split': 32, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79087, std: 0.05676, params: {'min_samples_split': 32, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79131, std: 0.05899, params: {'min_samples_split': 37, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79061, std: 0.05814, params: {'min_samples_split': 37, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79033, std: 0.05617, params: {'min_samples_split': 37, 'n_estimators': 70, 'max_depth': 27}, mean: 0.78871, std: 0.05524, params: {'min_samples_split': 42, 'n_estimators': 64, 'max_depth': 27}, mean: 0.78950, std: 0.05785, params: {'min_samples_split': 42, 'n_estimators': 67, 'max_depth': 27}, mean: 0.78963, std: 0.05734, params: {'min_samples_split': 42, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79064, std: 0.05723, params: {'min_samples_split': 47, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79182, std: 0.05667, params: {'min_samples_split': 47, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79163, std: 0.05668, params: {'min_samples_split': 47, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79067, std: 0.05792, params: {'min_samples_split': 52, 'n_estimators': 64, 'max_depth': 27}, mean: 0.79064, std: 0.05729, params: {'min_samples_split': 52, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79048, std: 0.05703, params: {'min_samples_split': 52, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79112, std: 0.05765, params: {'min_samples_split': 57, 'n_estimators': 64, 'max_depth': 27}, mean: 0.78820, std: 0.05598, params: {'min_samples_split': 57, 'n_estimators': 67, 'max_depth': 27}, mean: 0.79064, std: 0.05774, params: {'min_samples_split': 57, 'n_estimators': 70, 'max_depth': 27}, mean: 0.79026, std: 0.05854, params: {'min_samples_split': 62, 'n_estimators': 64, 'max_depth': 27}, mean: 0.78963, std: 0.05805, params: {'min_samples_split': 62, 'n_estimators': 67, 'max_depth': 27}, mean: 0.78998, std: 0.05874, params: {'min_samples_split': 62, 'n_estimators': 70, 'm ...
# ############# based on standard predict ################
# Accuracy on training data: 0.89
# Accuracy on test data:     0.81
# [[4465  933]
#  [1602 6503]]
# ########################################################

# %%
best_estimator_count = clfForest.get_params()['n_estimators']
best_max_depth = clfForest.get_params()['max_depth']
best_min_samples_split = clfForest.get_params()['min_samples_split']

print best_estimator_count , best_max_depth , best_min_samples_split
# Out:
# 64 30 7

# %%
# Fine search to find the best parameters
parameters = {"n_estimators":  range(best_estimator_count-2, best_estimator_count+3, 1) , 
              "max_depth" : range(best_max_depth-2, best_max_depth+3, 1) ,
              "min_samples_split": range(best_min_samples_split-2, best_min_samples_split+3, 1)}
clfForest, Xtrain, ytrain, Xtest, ytest = do_classify(clfForest, parameters, 
                                                       finalDataDF, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'min_samples_split': 6, 'n_estimators': 63, 'max_depth': 32} 0.797149749254 [mean: 0.79515, std: 0.05502, params: {'min_samples_split': 5, 'n_estimators': 62, 'max_depth': 28}, mean: 0.79575, std: 0.05508, params: {'min_samples_split': 5, 'n_estimators': 63, 'max_depth': 28}, mean: 0.79550, std: 0.05531, params: {'min_samples_split': 5, 'n_estimators': 64, 'max_depth': 28}, mean: 0.79575, std: 0.05594, params: {'min_samples_split': 5, 'n_estimators': 65, 'max_depth': 28}, mean: 0.79493, std: 0.05546, params: {'min_samples_split': 5, 'n_estimators': 66, 'max_depth': 28}, mean: 0.79261, std: 0.05742, params: {'min_samples_split': 6, 'n_estimators': 62, 'max_depth': 28}, mean: 0.79213, std: 0.05516, params: {'min_samples_split': 6, 'n_estimators': 63, 'max_depth': 28}, mean: 0.79182, std: 0.05443, params: {'min_samples_split': 6, 'n_estimators': 64, 'max_depth': 28}, mean: 0.79217, std: 0.05515, params: {'min_samples_split': 6, 'n_estimators': 65, 'max_depth': 28}, mean: 0.79290, std: 0.05441, params: {'min_samples_split': 6, 'n_estimators': 66, 'max_depth': 28}, mean: 0.79509, std: 0.05458, params: {'min_samples_split': 7, 'n_estimators': 62, 'max_depth': 28}, mean: 0.79496, std: 0.05452, params: {'min_samples_split': 7, 'n_estimators': 63, 'max_depth': 28}, mean: 0.79353, std: 0.05510, params: {'min_samples_split': 7, 'n_estimators': 64, 'max_depth': 28}, mean: 0.79388, std: 0.05465, params: {'min_samples_split': 7, 'n_estimators': 65, 'max_depth': 28}, mean: 0.79344, std: 0.05474, params: {'min_samples_split': 7, 'n_estimators': 66, 'max_depth': 28}, mean: 0.79401, std: 0.05543, params: {'min_samples_split': 8, 'n_estimators': 62, 'max_depth': 28}, mean: 0.79426, std: 0.05549, params: {'min_samples_split': 8, 'n_estimators': 63, 'max_depth': 28}, mean: 0.79331, std: 0.05552, params: {'min_samples_split': 8, 'n_estimators': 64, 'max_depth': 28}, mean: 0.79366, std: 0.05687, params: {'min_samples_split': 8, 'n_estimators': 65, 'max_depth': 28}, mean: 0.79404, std: 0.05655, params: {'min_samples_split': 8, 'n_estimators': 66, 'max_depth': 28}, mean: 0.79271, std: 0.05457, params: {'min_samples_split': 9, 'n_estimators': 62, 'max_depth': 28}, mean: 0.79274, std: 0.05529, params: {'min_samples_split': 9, 'n_estimators': 63, 'max_depth': 28}, mean: 0.79242, std: 0.05533, params: {'min_samples_split': 9, 'n_estimators': 64, 'max_depth': 28}, mean: 0.79394, std: 0.05622, params: {'min_samples_split': 9, 'n_estimators': 65, 'max_depth': 28}, mean: 0.79391, std: 0.05570, params: {'min_samples_split': 9, 'n_estimators': 66, 'max_depth': 28}, mean: 0.79455, std: 0.05281, params: {'min_samples_split': 5, 'n_estimators': 62, 'max_depth': 29}, mean: 0.79344, std: 0.05264, params: {'min_samples_split': 5, 'n_estimators': 63, 'max_depth': 29}, mean: 0.79413, std: 0.05303, params: {'min_samples_split': 5, 'n_estimators': 64, 'max_depth': 29}, mean: 0.79398, std: 0.05208, params: {'min_samples_split': 5, 'n_estimators': 65, 'max_depth': 29}, mean: 0.79350, std: 0.05253, params: {'min_samples_split': 5, 'n_estimators': 66, 'max_depth': 29}, mean: 0.79585, std: 0.05494, params: {'min_samples_split': 6, 'n_estimators': 62, 'max_depth': 29}, mean: 0.79490, std: 0.05489, params: {'min_samples_split': 6, 'n_estimators': 63, 'max_depth': 29}, mean: 0.79432, std: 0.05503, params: {'min_samples_split': 6, 'n_estimators': 64, 'max_depth': 29}, mean: 0.79525, std: 0.05531, params: {'min_samples_split': 6, 'n_estimators': 65, 'max_depth': 29}, mean: 0.79410, std: 0.05464, params: {'min_samples_split': 6, 'n_estimators': 66, 'max_depth': 29}, mean: 0.79309, std: 0.05205, params: {'min_samples_split': 7, 'n_estimators': 62, 'max_depth': 29}, mean: 0.79334, std: 0.05150, params: {'min_samples_split': 7, 'n_estimators': 63, 'max_depth': 29}, mean: 0.79255, std: 0.05230, params: {'min_samples_split': 7, 'n_estimators': 64, 'max_depth': 29}, mean: 0.79302, std: 0.05236, params: {'min_samples_split': 7, 'n_estimators': 65, 'max_depth': 29}, mean: 0.79337, st ...
# ############# based on standard predict ################
# Accuracy on training data: 0.90
# Accuracy on test data:     0.81
# [[4463  935]
#  [1593 6512]]
# ########################################################

# %%
# Performance metrics of the best fit Random Forest
print classification_report(ytest,clfForest.predict(Xtest))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.74      0.83      0.78      5398
#           1       0.87      0.80      0.84      8105
#
# avg / total       0.82      0.81      0.81     13503

# %%
# Printing metrics for Decision Tree for comparison purposes

from sklearn.metrics import classification_report
print classification_report(ytest,clfdt_entropy.predict(Xtest))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.72      0.82      0.77      5398
#           1       0.87      0.79      0.83      8105
#
# avg / total       0.81      0.80      0.80     13503

# %% [markdown]
# The hyperparameter search is now complete and the optimal parameters for n_estimators, max_depth, and min_samples_split were found. Random Forest improves over Decision Tree on all metrics being evaluated. The accuracy score of test set seems very promising to classify whether a bike is stolen or not given its features

# %% [markdown]
# Let us now procced to investigate significant features of this model to get some insight into factors contributing to the theft
# of the model

# %%
# Extracting Top 25 significant features from the best fit Random forest

signi_features = zip(features, clfForest.feature_importances_)
signi_features = pd.DataFrame(signi_features, columns = ["features", "importance"])
signi_features.sort(columns = ["importance"], ascending = False, inplace = True)
print "Top 25 significant features"
print signi_features.head(30)
# Out:
# Top 25 significant features
#                            features  importance
# 724                            year    0.305958
# 2       frame_material_slug=missing    0.049225
# 12           frame_size_std=unknown    0.047219
# 697     rear_gear_type_slug=missing    0.038305
# 18     front_gear_type_slug=missing    0.038004
# 52      handlebar_type_slug=missing    0.035724
# 4         frame_material_slug=steel    0.022348
# 0      frame_material_slug=aluminum    0.018475
# 49         handlebar_type_slug=drop    0.014403
# 20        front_tire_narrow=missing    0.013889
# 50         handlebar_type_slug=flat    0.012898
# 47     front_wheel_size_iso_bsd=nan    0.012529
# 19                front_tire_narrow    0.012119
# 9                 frame_size_std=XL    0.011829
# 533              manufacturer_id=47    0.010627
# 44   front_wheel_size_iso_bsd=622.0    0.010521
# 726                           black    0.009759
# 16           front_gear_type_slug=3    0.009046
# 723     rear_wheel_size_iso_bsd=nan    0.008910
# 14           front_gear_type_slug=2    0.008204
# 64              manufacturer_id=101    0.008009
# 720   rear_wheel_size_iso_bsd=622.0    0.007845
# 7                  frame_size_std=M    0.007839
# 8                  frame_size_std=S    0.007671
# 10                frame_size_std=XS    0.007141
# 6                  frame_size_std=L    0.007114
# 13           front_gear_type_slug=1    0.007105
# 476             manufacturer_id=307    0.007030
# 761                           white    0.006685
# 415             manufacturer_id=201    0.006618
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
# Create plot of Top 10 significant factors using feature importances

importance_list = clfForest.feature_importances_
name_list = features
importance_list, name_list = zip(*sorted(zip(importance_list, name_list) )[-10:])
plt.barh(range(len(name_list)),importance_list,align='center')
plt.yticks(range(len(name_list)),name_list)
plt.xlabel('Relative Importance in the Random Forest')
plt.ylabel('Features')
plt.title('Relative importance of Each Feature')
plt.show()

# %% [markdown]
# The attribute of the random forest feature_importances was used to obtain the relative importance of the features. The manufacturing year of the bike, whether the bike is expensive or not, and the frame size seemed to have an important role in classifying stolen from the non-stolen ones as seen in the bar graph above.

# %% [markdown]
# The model year of the bike seems way more significant than expected in determining whether bike gets stolen. That too bikes older than 2013 seems to have a high propensity to gets stolen.

# %%
fig, ax = plt.subplots(figsize=(10,10))
colorDict = { True : "r", False :"g"}
for label, df in finalDataDF['year'].groupby(finalDataDF["stolen"]):
    df.plot(kind="kde", ax=ax, label=label , color = colorDict[label] )
    ax.set_xlim([1970 , 2020])
plt.legend(["Not stolen" , "Stolen"])
plt.title("Bike Model Year - Stolen vs non-Stolen bikes\n")
plt.xlabel("Bike Model Year")

# %% [markdown]
# After evaluating multiple possibilities, we found out the best explanation of this phenomenon from the history of bikeIndex.org website. Following is an excerpt from the about page of bikeindex.org

# %% [markdown]
# "Bryan started StolenBicycleRegistry.com in 2004 because he was tired of having bikes stolen. Seth started the Bike Index because he was a bike mechanic and wished there was an easy way to register bikes for his customers. We merged Bike Index and SBR in July of 2014 because it made perfect sense—Seth makes sure registration is effortless, and Bryan recovers stolen bikes."

# %% [markdown]
# Apparently the site bikeindex.org as we know it today is the merger of StolenBicycleRegistry.com & bikeindex.org in the year of 2014.  Both sites served a different purposes before 2014 and thus can be reasonably expected to have different growth trajectories. It seems StolenBicycleRegistry, primarily used to recover stolen bikes had a faster growth than bikeindex.org, but the proportion of stolen bikes to non-stolen bikes have droppped since.
#
# We can expect the imbalance of years prior to 2014 to stay as is or probably widen as we expect long time bike owners to make use of the site only if their bike ever gets stolen. It seems like BikeIndex.org could use some marketing to widen it's user base among long time bike owners as most long time bike owners are probably not aware of the site. The new bike owners can be expected to have been advised by the bike shops to register their bike with BikeIndex.org

# %% [markdown]
# We shall proceed to understand the extend of this bias, but before we wanted to see if RandomForest gives best performance metrics or if another algorithm is able to best these numbers. We have chosen to try LogisticRegression and SVC as the challengers.

# %% [markdown]
# LogisticRegression and SVC are difficult to be readily run against current dataset. Due to it's high dimensional nature. In order to run these algorithms, we first reduce the dataset to it's principal components.

# %%
from sklearn.decomposition import PCA

componentsCount = 20
pca = PCA(n_components=componentsCount)

data_PCA = pca.fit_transform(finalDataDF[features])
columns_PCA = [ x[0] + "_" + x[1] for x in zip( ['pca'] * componentsCount , [ str(i) for i in range(componentsCount)])] 

final_PCA = pd.DataFrame ( data_PCA , columns = columns_PCA)
final_PCA['stolen'] = finalDataDF['stolen']

# %% [markdown]
# Next, we proceed to run Logistic Regression on the reduced dataset

# %%
from sklearn.linear_model import LogisticRegression
clflog,X_train,y_train,X_test,y_test  = do_classify(LogisticRegression(penalty="l1"), {"C": [0.001, 0.01, 0.1, 1, 10, 100]}, final_PCA, columns_PCA, u'stolen', 1, mask=mask)
# Out:
# using mask
# BEST {'C': 10} 0.791991583117 [mean: 0.75350, std: 0.05844, params: {'C': 0.001}, mean: 0.77937, std: 0.04936, params: {'C': 0.01}, mean: 0.78983, std: 0.04670, params: {'C': 0.1}, mean: 0.79168, std: 0.04708, params: {'C': 1}, mean: 0.79199, std: 0.04672, params: {'C': 10}, mean: 0.79199, std: 0.04672, params: {'C': 100}]
# ############# based on standard predict ################
# Accuracy on training data: 0.80
# Accuracy on test data:     0.80
# [[1043  956]
#  [ 405 4521]]
# ########################################################
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:18: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 45009 but corresponding boolean dimension is 23083

# %%
print classification_report(y_test,clflog.predict(X_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.72      0.52      0.61      1999
#           1       0.83      0.92      0.87      4926
#
# avg / total       0.80      0.80      0.79      6925

# %% [markdown]
# Logistic regression did not improve over the performance metrics of the RandomForest model. Next we attempt running SVC for this classification task

# %%
from sklearn.svm import LinearSVC
clfsvm=LinearSVC(loss="hinge")
Cs=[0.001, 0.01, 0.1, 1.0, 10.0, 100.0]
Xmatrix=final_PCA[columns_PCA].values
Yresp=final_PCA['stolen'].values

Xmatrix_train=Xmatrix[mask]
Xmatrix_test=Xmatrix[~mask]
Yresp_train=Yresp[mask]
Yresp_test=Yresp[~mask]

from sklearn.grid_search import GridSearchCV
gs=GridSearchCV(clfsvm, param_grid={'C':Cs}, cv=5)
gs.fit(Xmatrix_train, Yresp_train)
print "BEST", gs.best_params_, gs.best_score_, gs.grid_scores_

best = gs.best_estimator_
best.fit(Xmatrix_train, Yresp_train)
best.score(Xmatrix_test, Yresp_test)

clfsvm, X_train, y_train, X_test, y_test = do_classify(LinearSVC(loss="hinge"), {"C": [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]}, final_PCA, columns_PCA, u'stolen', 1, mask=mask)
# Out:
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 45009 but corresponding boolean dimension is 23083
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:8: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 45009 but corresponding boolean dimension is 23083
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:9: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 45009 but corresponding boolean dimension is 23083
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 45009 but corresponding boolean dimension is 23083
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'C': 0.001} 0.785617031811 [mean: 0.78562, std: 0.05670, params: {'C': 0.001}, mean: 0.78314, std: 0.05533, params: {'C': 0.01}, mean: 0.78141, std: 0.05416, params: {'C': 0.1}, mean: 0.78135, std: 0.05422, params: {'C': 1.0}, mean: 0.78246, std: 0.05336, params: {'C': 10.0}, mean: 0.77349, std: 0.02982, params: {'C': 100.0}]
# using mask
# BEST {'C': 0.001} 0.785617031811 [mean: 0.78562, std: 0.05670, params: {'C': 0.001}, mean: 0.78314, std: 0.05533, params: {'C': 0.01}, mean: 0.78147, std: 0.05422, params: {'C': 0.1}, mean: 0.78135, std: 0.05424, params: {'C': 1.0}, mean: 0.78283, std: 0.05235, params: {'C': 10.0}, mean: 0.76835, std: 0.04562, params: {'C': 100.0}]
# ############# based on standard predict ################
# Accuracy on training data: 0.79
# Accuracy on test data:     0.79
# [[ 993 1006]
#  [ 467 4459]]
# ########################################################
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:18: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 45009 but corresponding boolean dimension is 23083

# %%
print classification_report(y_test,clfsvm.predict(X_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.68      0.50      0.57      1999
#           1       0.82      0.91      0.86      4926
#
# avg / total       0.78      0.79      0.78      6925

# %% [markdown]
# SVC performance is sub-par to RandomForests as well

# %% [markdown]
# Next we procced to investigate the ROC curves of all the four classifiers we have fitted.

# %%
ax = make_roc("logistic-with-lasso",clflog, y_test, X_test, None, labe=300, skip=400)
make_roc("svm",clfsvm, y_test, X_test, ax, labe=300, proba=False, skip=400);
make_roc("Random Forest",clfForest, ytest, Xtest, ax, labe=300, skip=400);
make_roc("Decision tree",clfdt, ytest, Xtest, ax, labe=60)

# %% [markdown]
# As expected , RandomForest gives the best ROC curve characterisitics when compared with other classifiers

# %% [markdown]
# We now revisit the year bias issue identified earlier. To understand what the feature importances would look like if the dataset was balanced across the bike model years, we proceed to create a balanced dataset by means of over-sampling/under-sampling proportions of stolen bikes to non-stolen bikes across the years. Let us first determine what the ratio of stolen bikes to total bikes should look like across the years.

# %%
# Determining ratio of stolen bikes to non-stolen Bikes for the overall sample
finalDataDF.stolen.value_counts()
# Out:
# 1    27125
# 0    17884
# Name: stolen, dtype: int64

# %%
print "ratio = " , str( (27125 * 1.0) / (27125 + 17884))
# Out:
# ratio =  0.602657246329

# %% [markdown]
# Goal here is get the proportion of stolen bikes to all bikes in every Bike Model Year at near 0.60. We do this by determining first, for each year which category - stolen or non-stolen bikes needs to be over-sampled or under-sampled to achieve this ratio. Also we need to determine, how much to oversample or undersample based on proportions of data already present. Preference is given to over-sampling than under-sampling to balance the dataset as this ensures minimal loss of useful information.
#
# We shall perform under-sampling of stolen/non-stolen segment in cases where over-sampling of the complementary segment could be causing too much duplication of information. We arbitrarily fix over-sampling ratio threshold at 80% . If we need to over-sample beyond 80% of the data falling short desired proportion, we shall choose the under-sample the complementary segment instead to balance the ratio of stolen bikes to total bikes in that year at 0.60. Also, we shall ignore any year which has less than 100 records in total to reduce noisy data.

# %%
# Oversampling / Under-sampling across years to balance the ratio

balanceRatio =  0.602657246329
samplingRatioDict = {}
finalDFBalanced = None
for year in np.unique (finalDataDF.year) :
    recordsCount = len(np.where(finalDataDF['year'] == year)[0])
    stolenDetails = dict (  finalDataDF.iloc[ np.where(finalDataDF['year'] == year)]['stolen'].value_counts())
    
    # Perform balancing only for years with 100 or more records.
    if recordsCount >= 100 :
        ratioInThatYear = ( stolenDetails[1] * 1.0 / (stolenDetails[1] + stolenDetails[0]) )
        
        # Determining which segment to oversample or under sample.
        if ratioInThatYear > balanceRatio :
            portionToBeOverSampled = 'stolen_False'
            portionToBeUnderSampled = 'stolen_True'
           
            overSampleRatio = (( 1 - balanceRatio ) / (1 -ratioInThatYear ))*(ratioInThatYear/balanceRatio)
            underSampleRatio =  1.0 / overSampleRatio
        else :
            portionToBeOverSampled = 'stolen_True'
            portionToBeUnderSampled = 'stolen_False'
            
            underSampleRatio  = (( 1 - balanceRatio ) / (1 -ratioInThatYear ))*(ratioInThatYear/balanceRatio)
            overSampleRatio =  1.0 / underSampleRatio
                    
        tempDF = finalDataDF.iloc[ np.where(finalDataDF['year'] == year)]

        # Perform over-sampling or under-sampling as per the choice above.
        print "Ratio of Stolen Bikes to Total" , year , ( stolenDetails[1] * 1.0 / (stolenDetails[1] + stolenDetails[0]) )
        if overSampleRatio <= 0.8 :
            print "Column to OverSampled " , portionToBeOverSampled
            print "OverSampleRatio" , overSampleRatio
            
            if portionToBeOverSampled == 'stolen_False' :
                print "oversampling stolen_False" , overSampleRatio
                retainedPortion = tempDF.copy()
                overSampledPortion = retainedPortion.iloc[np.where(retainedPortion['stolen'] == False)].sample( frac = overSampleRatio , replace = True , axis = 0)
                retainedPortion = pd.concat ([retainedPortion ,overSampledPortion] )
            else :
                print "oversampling stolen_True" , overSampleRatio
                retainedPortion = tempDF.copy()
                overSampledPortion = retainedPortion.iloc[np.where(retainedPortion['stolen'] == True)].sample( frac = overSampleRatio , replace = True ,  axis = 0)
                retainedPortion = pd.concat ([retainedPortion ,overSampledPortion] )
  
            
        else :
            if portionToBeUnderSampled == 'stolen_False' :
                print "undersampling stolen_False" , underSampleRatio
                retainedPortion = tempDF.iloc[np.where(tempDF['stolen'] == True)]
                underSampledPortion = tempDF.iloc[np.where(tempDF['stolen'] == False)].sample( frac = underSampleRatio , replace = True  , axis = 0)
                retainedPortion = pd.concat ([retainedPortion ,underSampledPortion] )

            else :
                print "undersampling stolen_True" , underSampleRatio
                retainedPortion = tempDF.iloc[np.where(tempDF['stolen'] == False)]
                print tempDF.iloc[np.where(tempDF['stolen'] == True)].shape
                
                underSampledPortion = tempDF.iloc[np.where(tempDF['stolen'] == True)].sample( frac = underSampleRatio , replace = True , axis = 0)
                print underSampledPortion.shape
                retainedPortion = pd.concat ([retainedPortion ,underSampledPortion] )

        if finalDFBalanced is None :
            finalDFBalanced = retainedPortion.copy()
        else :
            finalDFBalanced = pd.concat([finalDFBalanced , retainedPortion])
    else :
        print "Skipping year " + str(year) + " as there are less 100 records in the dataset"
# Out:
# Skipping year 1884.0 as there are less 100 records in the dataset
# Skipping year 1885.0 as there are less 100 records in the dataset
# Skipping year 1908.0 as there are less 100 records in the dataset
# Skipping year 1910.0 as there are less 100 records in the dataset
# Skipping year 1920.0 as there are less 100 records in the dataset
# Skipping year 1935.0 as there are less 100 records in the dataset
# Skipping year 1938.0 as there are less 100 records in the dataset
# Skipping year 1940.0 as there are less 100 records in the dataset
# Skipping year 1941.0 as there are less 100 records in the dataset
# Skipping year 1942.0 as there are less 100 records in the dataset
# Skipping year 1943.0 as there are less 100 records in the dataset
# Skipping year 1948.0 as there are less 100 records in the dataset
# Skipping year 1950.0 as there are less 100 records in the dataset
# Skipping year 1952.0 as there are less 100 records in the dataset
# Skipping year 1953.0 as there are less 100 records in the dataset
# Skipping year 1954.0 as there are less 100 records in the dataset
# Skipping year 1955.0 as there are less 100 records in the dataset
# Skipping year 1956.0 as there are less 100 records in the dataset
# Skipping year 1957.0 as there are less 100 records in the dataset
# Skipping year 1958.0 as there are less 100 records in the dataset
# Skipping year 1959.0 as there are less 100 records in the dataset
# Skipping year 1960.0 as there are less 100 records in the dataset
# Skipping year 1961.0 as there are less 100 records in the dataset
# Skipping year 1962.0 as there are less 100 records in the dataset
# Skipping year 1963.0 as there are less 100 records in the dataset
# Skipping year 1964.0 as there are less 100 records in the dataset
# Skipping year 1965.0 as there are less 100 records in the dataset
# Skipping year 1966.0 as there are less 100 records in the dataset
# Skipping year 1967.0 as there are less 100 records in the dataset
# Skipping year 1968.0 as there are less 100 records in the dataset
# Skipping year 1969.0 as there are less 100 records in the dataset
# Ratio of Stolen Bikes to Total 1970.0 0.88038277512
# undersampling stolen_True 0.206075931365
# (184, 764)
# (38, 764)
# Skipping year 1971.0 as there are less 100 records in the dataset
# Skipping year 1972.0 as there are less 100 records in the dataset
# Skipping year 1973.0 as there are less 100 records in the dataset
# Skipping year 1974.0 as there are less 100 records in the dataset
# Skipping year 1975.0 as there are less 100 records in the dataset
# Skipping year 1976.0 as there are less 100 records in the dataset
# Skipping year 1977.0 as there are less 100 records in the dataset
# Skipping year 1978.0 as there are less 100 records in the dataset
# Skipping year 1979.0 as there are less 100 records in the dataset
# Ratio of Stolen Bikes to Total 1980.0 0.885286783042
# undersampling stolen_True 0.196532584008
# (355, 764)
# (70, 764)
# Skipping year 1981.0 as there are less 100 records in the dataset
# Skipping year 1982.0 as there are less 100 records in the dataset
# Ratio of Stolen Bikes to Total 1983.0 0.6
# undersampling stolen_False 0.988976958523
# Ratio of Stolen Bikes to Total 1984.0 0.503703703704
# undersampling stolen_False 0.6691585391
# Ratio of Stolen Bikes to Total 1985.0 0.571428571429
# undersampling stolen_False 0.879090629799
# Ratio of Stolen Bikes to Total 1986.0 0.603448275862
# undersampling stolen_True 0.996700961756
# (105, 764)
# (105, 764)
# Ratio of Stolen Bikes to Total 1987.0 0.622516556291
# undersampling stolen_True 0.919712497087
# (94, 764)
# (86, 764)
# Ratio of Stolen Bikes to Total 1988.0 0.612903225806
# undersampling stolen_True 0.957927697797
# (76, 764)
# (73, 764)
# Ratio of Stolen Bikes to Total 1989.0 0.606060606061
# undersampling stolen_True 0.98586725565
# (80, 764)
# (79, 764)
# Ratio of Stolen Bikes to Total 1990.0 0.864077669903
# undersampling stolen_True 0.238584988403
# (267, 764)
# (64, 764)
# Ratio of Stolen Bikes to Total 1991.0 0.611842105263
# undersampling stolen_True 0.962219488558
# (93, 764)
# (89, 764)
# Ratio of Stolen Bikes to Total 1992.0 0.645833333333
# undersampling stolen_True 0.831749049431
# (124, 764)
# (103, 764)
# Ratio of Stolen Bikes to Total 1993.0 0.664705882353
# undersampling stolen_True 0.765070572798
# (113, 764)
# (86, 764)
# Ratio of Stolen Bikes to Total 1994.0 0.714285714286
# undersampling stolen_True 0.606687541938
# (125, 764)
# (76, 764)
# Ratio of Stolen Bikes to Total 1995.0 0.733082706767
# undersampling stolen_True 0.552241224072
# (195, 764)
# (108, 764)
# Ratio of Stolen Bikes to Total 1996.0 0.764462809917
# undersampling stolen_True 0.467313376898
# (185, 764)
# (86, 764)
# Ratio of Stolen Bikes to Total 1997.0 0.746428571429
# undersampling stolen_True 0.515248988967
# (209, 764)
# (108, 764)
# Ratio of Stolen Bikes to Total 1998.0 0.790909090909
# undersampling stolen_True 0.400971651281
# (261, 764)
# (105, 764)
# Ratio of Stolen Bikes to Total 1999.0 0.805486284289
# undersampling stolen_True 0.366266472687
# (323, 764)
# (118, 764)
# Ratio of Stolen Bikes to Total 2000.0 0.823630136986
# undersampling stolen_True 0.324785950206
# (481, 764)
# (156, 764)
# Ratio of Stolen Bikes to Total 2001.0 0.800387596899
# undersampling stolen_True 0.378261603024
# (413, 764)
# (156, 764)
# Ratio of Stolen Bikes to Total 2002.0 0.823223570191
# undersampling stolen_True 0.325695417251
# (475, 764)
# (155, 764)
# Ratio of Stolen Bikes to Total 2003.0 0.84238410596
# undersampling stolen_True 0.283788590765
# (636, 764)
# (180, 764)
# Ratio of Stolen Bikes to Total 2004.0 0.857446808511
# undersampling stolen_True 0.252159214081
# (806, 764)
# (203, 764)
# Ratio of Stolen Bikes to Total 2005.0 0.871378091873
# undersampling stolen_True 0.223879019937
# (1233, 764)
# (276, 764)
# Ratio of Stolen Bikes to Total 2006.0 0.83542039356
# undersampling stolen_True 0.298796862197
# (1401, 764)
# (419, 764)
# Ratio of Stolen Bikes to Total 2007.0 0.854581673307
# undersampling stolen_True 0.258089688587
# (1716, 764)
# (443, 764)
# Ratio of Stolen Bikes to Total 2008.0 0.835453100159
# undersampling stolen_True 0.298725787776
# (2102, 764)
# (628, 764)
# Ratio of Stolen Bikes to Total 2009.0 0.847148288973
# undersampling stolen_True 0.273662917257
# (2228, 764)
# (610, 764)
# Ratio of Stolen Bikes to Total 2010.0 0.802955665025
# undersampling stolen_True 0.372200945974
# (2282, 764)
# (849, 764)
# Ratio of Stolen Bikes to Total 2011.0 0.759933774834
# undersampling stolen_True 0.479137764603
# (2295, 764)
# (1100, 764)
# Ratio of Stolen Bikes to Total 2012.0 0.643622722401
# undersampling stolen_True 0.839815186072
# (2402, 764)
# (2017, 764)
# Ratio of Stolen Bikes to Total 2013.0 0.483074907185
# undersampling stolen_False 0.616143369174
# Ratio of Stolen Bikes to Total 2014.0 0.333579744964
# undersampling stolen_False 0.330024664473
# Ratio of Stolen Bikes to Total 2015.0 0.161300505051
# undersampling stolen_False 0.12680146175
# Ratio of Stolen Bikes to Total 2016.0 0.0712643678161
# undersampling stolen_False 0.0505912305515

# %% [markdown]
# Let us create a distribution plot and ensure that the data is now balanced.

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( finalDFBalanced , 'year' , 'stolen' , 20 , None)

# %%
finalDFBalanced.shape
# Out:
# (23083, 764)

# %% [markdown]
# Now proceeding to create train & test portions on this balanced dataset

# %%
# Creating a mask column to separate train and test records

from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix

itrain, itest = train_test_split(xrange(finalDFBalanced.shape[0]), train_size=0.7)
mask=np.ones(finalDFBalanced.shape[0], dtype='int')
mask[itrain]=1
mask[itest]=0
mask = (mask==1)

# %%
clfForest_balanced = RandomForestClassifier()
parameters = {"n_estimators": range(1, 101, 5)}
clfForest_balanced, Xtrain1, ytrain1, Xtest1, ytest1 = do_classify(clfForest_balanced, parameters, 
                                                       finalDFBalanced, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'n_estimators': 81} 0.724408961505 [mean: 0.67081, std: 0.08953, params: {'n_estimators': 1}, mean: 0.70448, std: 0.11201, params: {'n_estimators': 6}, mean: 0.70850, std: 0.09747, params: {'n_estimators': 11}, mean: 0.71315, std: 0.10827, params: {'n_estimators': 16}, mean: 0.71655, std: 0.10292, params: {'n_estimators': 21}, mean: 0.71822, std: 0.10611, params: {'n_estimators': 26}, mean: 0.71717, std: 0.10224, params: {'n_estimators': 31}, mean: 0.71977, std: 0.10491, params: {'n_estimators': 36}, mean: 0.71562, std: 0.10246, params: {'n_estimators': 41}, mean: 0.71612, std: 0.10347, params: {'n_estimators': 46}, mean: 0.71624, std: 0.10099, params: {'n_estimators': 51}, mean: 0.71865, std: 0.10444, params: {'n_estimators': 56}, mean: 0.71958, std: 0.10216, params: {'n_estimators': 61}, mean: 0.71890, std: 0.10306, params: {'n_estimators': 66}, mean: 0.71958, std: 0.10030, params: {'n_estimators': 71}, mean: 0.72094, std: 0.09977, params: {'n_estimators': 76}, mean: 0.72441, std: 0.09717, params: {'n_estimators': 81}, mean: 0.72342, std: 0.10054, params: {'n_estimators': 86}, mean: 0.72113, std: 0.09756, params: {'n_estimators': 91}, mean: 0.72014, std: 0.09939, params: {'n_estimators': 96}]
# ############# based on standard predict ################
# Accuracy on training data: 0.95
# Accuracy on test data:     0.78
# [[2018  766]
#  [ 763 3378]]
# ########################################################

# %%
best_estimator_count = clfForest_balanced.get_params()['n_estimators']
print best_estimator_count
# Out:
# 81

# %%
# Continuing coarse search after additon of max_depth parameter to the search

parameters = {"n_estimators": range(best_estimator_count -6, best_estimator_count+7, 3) , "max_depth" : range ( 1, 49 , 5)}
clfForest_balanced, Xtrain1, ytrain1, Xtest1, ytest1 = do_classify(clfForest_balanced, parameters, 
                                                       finalDFBalanced, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'n_estimators': 75, 'max_depth': 36} 0.72768907043 [mean: 0.60595, std: 0.00266, params: {'n_estimators': 75, 'max_depth': 1}, mean: 0.60552, std: 0.00179, params: {'n_estimators': 78, 'max_depth': 1}, mean: 0.60540, std: 0.00154, params: {'n_estimators': 81, 'max_depth': 1}, mean: 0.60552, std: 0.00179, params: {'n_estimators': 84, 'max_depth': 1}, mean: 0.60527, std: 0.00130, params: {'n_estimators': 87, 'max_depth': 1}, mean: 0.68672, std: 0.11331, params: {'n_estimators': 75, 'max_depth': 6}, mean: 0.68777, std: 0.11399, params: {'n_estimators': 78, 'max_depth': 6}, mean: 0.69099, std: 0.11256, params: {'n_estimators': 81, 'max_depth': 6}, mean: 0.69093, std: 0.11182, params: {'n_estimators': 84, 'max_depth': 6}, mean: 0.69056, std: 0.11390, params: {'n_estimators': 87, 'max_depth': 6}, mean: 0.70275, std: 0.12295, params: {'n_estimators': 75, 'max_depth': 11}, mean: 0.70071, std: 0.12374, params: {'n_estimators': 78, 'max_depth': 11}, mean: 0.70132, std: 0.12512, params: {'n_estimators': 81, 'max_depth': 11}, mean: 0.70151, std: 0.12495, params: {'n_estimators': 84, 'max_depth': 11}, mean: 0.70015, std: 0.12592, params: {'n_estimators': 87, 'max_depth': 11}, mean: 0.71042, std: 0.12264, params: {'n_estimators': 75, 'max_depth': 16}, mean: 0.71073, std: 0.12337, params: {'n_estimators': 78, 'max_depth': 16}, mean: 0.71215, std: 0.12386, params: {'n_estimators': 81, 'max_depth': 16}, mean: 0.71129, std: 0.12304, params: {'n_estimators': 84, 'max_depth': 16}, mean: 0.71017, std: 0.12433, params: {'n_estimators': 87, 'max_depth': 16}, mean: 0.72057, std: 0.11582, params: {'n_estimators': 75, 'max_depth': 21}, mean: 0.71983, std: 0.11517, params: {'n_estimators': 78, 'max_depth': 21}, mean: 0.72001, std: 0.11544, params: {'n_estimators': 81, 'max_depth': 21}, mean: 0.71834, std: 0.11636, params: {'n_estimators': 84, 'max_depth': 21}, mean: 0.71556, std: 0.11831, params: {'n_estimators': 87, 'max_depth': 21}, mean: 0.72138, std: 0.11576, params: {'n_estimators': 75, 'max_depth': 26}, mean: 0.72070, std: 0.11673, params: {'n_estimators': 78, 'max_depth': 26}, mean: 0.72162, std: 0.11569, params: {'n_estimators': 81, 'max_depth': 26}, mean: 0.72187, std: 0.11569, params: {'n_estimators': 84, 'max_depth': 26}, mean: 0.72200, std: 0.11556, params: {'n_estimators': 87, 'max_depth': 26}, mean: 0.72466, std: 0.11378, params: {'n_estimators': 75, 'max_depth': 31}, mean: 0.72336, std: 0.11338, params: {'n_estimators': 78, 'max_depth': 31}, mean: 0.72255, std: 0.11356, params: {'n_estimators': 81, 'max_depth': 31}, mean: 0.72261, std: 0.11495, params: {'n_estimators': 84, 'max_depth': 31}, mean: 0.72261, std: 0.11507, params: {'n_estimators': 87, 'max_depth': 31}, mean: 0.72769, std: 0.10651, params: {'n_estimators': 75, 'max_depth': 36}, mean: 0.72701, std: 0.10845, params: {'n_estimators': 78, 'max_depth': 36}, mean: 0.72645, std: 0.10786, params: {'n_estimators': 81, 'max_depth': 36}, mean: 0.72447, std: 0.10745, params: {'n_estimators': 84, 'max_depth': 36}, mean: 0.72441, std: 0.10769, params: {'n_estimators': 87, 'max_depth': 36}, mean: 0.72466, std: 0.10918, params: {'n_estimators': 75, 'max_depth': 41}, mean: 0.72472, std: 0.10731, params: {'n_estimators': 78, 'max_depth': 41}, mean: 0.72651, std: 0.10706, params: {'n_estimators': 81, 'max_depth': 41}, mean: 0.72515, std: 0.10567, params: {'n_estimators': 84, 'max_depth': 41}, mean: 0.72589, std: 0.10552, params: {'n_estimators': 87, 'max_depth': 41}, mean: 0.72695, std: 0.10761, params: {'n_estimators': 75, 'max_depth': 46}, mean: 0.72769, std: 0.10736, params: {'n_estimators': 78, 'max_depth': 46}, mean: 0.72744, std: 0.10695, params: {'n_estimators': 81, 'max_depth': 46}, mean: 0.72558, std: 0.10702, params: {'n_estimators': 84, 'max_depth': 46}, mean: 0.72515, std: 0.10646, params: {'n_estimators': 87, 'max_depth': 46}]
# ############# based on standard predict ################
# Accuracy on training data: 0.91
# Accuracy on test data:     0.77
# [[1839  945]
#  [ 618 3523]]
# ########################################################

# %%
best_estimator_count = clfForest.get_params()['n_estimators']
best_max_depth = clfForest.get_params()['max_depth']

print best_estimator_count , best_max_depth
# Out:
# 63 32

# %%
# Continuing coarse search after addition of min_samples_split parameter

parameters = {"n_estimators":  range(best_estimator_count-4, best_estimator_count+4, 3) , 
              "max_depth" : range(best_max_depth-4, best_max_depth+4, 3) ,
              "min_samples_split": range(2,100,5)}
clfForest_balanced, Xtrain1, ytrain1, Xtest1, ytest1 = do_classify(clfForest_balanced, parameters, 
                                                       finalDFBalanced, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'min_samples_split': 2, 'n_estimators': 65, 'max_depth': 34} 0.727750959277 [mean: 0.72534, std: 0.11319, params: {'min_samples_split': 2, 'n_estimators': 59, 'max_depth': 28}, mean: 0.72596, std: 0.11255, params: {'min_samples_split': 2, 'n_estimators': 62, 'max_depth': 28}, mean: 0.72682, std: 0.11326, params: {'min_samples_split': 2, 'n_estimators': 65, 'max_depth': 28}, mean: 0.72020, std: 0.11635, params: {'min_samples_split': 7, 'n_estimators': 59, 'max_depth': 28}, mean: 0.72032, std: 0.11735, params: {'min_samples_split': 7, 'n_estimators': 62, 'max_depth': 28}, mean: 0.72107, std: 0.11759, params: {'min_samples_split': 7, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71958, std: 0.11847, params: {'min_samples_split': 12, 'n_estimators': 59, 'max_depth': 28}, mean: 0.72094, std: 0.11727, params: {'min_samples_split': 12, 'n_estimators': 62, 'max_depth': 28}, mean: 0.72119, std: 0.11850, params: {'min_samples_split': 12, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71717, std: 0.12121, params: {'min_samples_split': 17, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71704, std: 0.12089, params: {'min_samples_split': 17, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71772, std: 0.12078, params: {'min_samples_split': 17, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71729, std: 0.12226, params: {'min_samples_split': 22, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71735, std: 0.12269, params: {'min_samples_split': 22, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71723, std: 0.12258, params: {'min_samples_split': 22, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71921, std: 0.12341, params: {'min_samples_split': 27, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71766, std: 0.12650, params: {'min_samples_split': 27, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71723, std: 0.12476, params: {'min_samples_split': 27, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71946, std: 0.12097, params: {'min_samples_split': 32, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71803, std: 0.12427, params: {'min_samples_split': 32, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71915, std: 0.12497, params: {'min_samples_split': 32, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71451, std: 0.12712, params: {'min_samples_split': 37, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71407, std: 0.12701, params: {'min_samples_split': 37, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71568, std: 0.12382, params: {'min_samples_split': 37, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71414, std: 0.12881, params: {'min_samples_split': 42, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71259, std: 0.12478, params: {'min_samples_split': 42, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71426, std: 0.12685, params: {'min_samples_split': 42, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71135, std: 0.12761, params: {'min_samples_split': 47, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71203, std: 0.12664, params: {'min_samples_split': 47, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71420, std: 0.12388, params: {'min_samples_split': 47, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71414, std: 0.12493, params: {'min_samples_split': 52, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71488, std: 0.12474, params: {'min_samples_split': 52, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71463, std: 0.12548, params: {'min_samples_split': 52, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71110, std: 0.12948, params: {'min_samples_split': 57, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71048, std: 0.12946, params: {'min_samples_split': 57, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71643, std: 0.12155, params: {'min_samples_split': 57, 'n_estimators': 65, 'max_depth': 28}, mean: 0.71463, std: 0.12742, params: {'min_samples_split': 62, 'n_estimators': 59, 'max_depth': 28}, mean: 0.71265, std: 0.12753, params: {'min_samples_split': 62, 'n_estimators': 62, 'max_depth': 28}, mean: 0.71166, std: 0.12636, params: {'min_samples_split': 62, 'n_estimators': 65, 'm ...
# ############# based on standard predict ################
# Accuracy on training data: 0.91
# Accuracy on test data:     0.77
# [[1813  971]
#  [ 613 3528]]
# ########################################################

# %%
best_estimator_count = clfForest.get_params()['n_estimators']
best_max_depth = clfForest.get_params()['max_depth']
best_min_samples_split = clfForest.get_params()['min_samples_split']

print best_estimator_count , best_max_depth , best_min_samples_split
# Out:
# 63 32 6

# %%
# Fine search to find the best parameters
parameters = {"n_estimators":  range(best_estimator_count-2, best_estimator_count+3, 1) , 
              "max_depth" : range(best_max_depth-2, best_max_depth+3, 1) ,
              "min_samples_split": range(best_min_samples_split-2, best_min_samples_split+3, 1)}
clfForest_balanced, Xtrain1, ytrain1, Xtest1, ytest1 = do_classify(clfForest_balanced, parameters, 
                                                       finalDFBalanced, features, 'stolen', 1, mask=mask, 
                                                       n_jobs = 30, score_func='accuracy')
# Out:
# using mask
# /home/anusha/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# BEST {'min_samples_split': 6, 'n_estimators': 63, 'max_depth': 34} 0.729607624706 [mean: 0.72305, std: 0.11349, params: {'min_samples_split': 4, 'n_estimators': 61, 'max_depth': 30}, mean: 0.72292, std: 0.11509, params: {'min_samples_split': 4, 'n_estimators': 62, 'max_depth': 30}, mean: 0.72410, std: 0.11392, params: {'min_samples_split': 4, 'n_estimators': 63, 'max_depth': 30}, mean: 0.72274, std: 0.11312, params: {'min_samples_split': 4, 'n_estimators': 64, 'max_depth': 30}, mean: 0.72292, std: 0.11376, params: {'min_samples_split': 4, 'n_estimators': 65, 'max_depth': 30}, mean: 0.72509, std: 0.11630, params: {'min_samples_split': 5, 'n_estimators': 61, 'max_depth': 30}, mean: 0.72268, std: 0.11523, params: {'min_samples_split': 5, 'n_estimators': 62, 'max_depth': 30}, mean: 0.72416, std: 0.11414, params: {'min_samples_split': 5, 'n_estimators': 63, 'max_depth': 30}, mean: 0.72497, std: 0.11326, params: {'min_samples_split': 5, 'n_estimators': 64, 'max_depth': 30}, mean: 0.72528, std: 0.11335, params: {'min_samples_split': 5, 'n_estimators': 65, 'max_depth': 30}, mean: 0.72348, std: 0.11635, params: {'min_samples_split': 6, 'n_estimators': 61, 'max_depth': 30}, mean: 0.72206, std: 0.11633, params: {'min_samples_split': 6, 'n_estimators': 62, 'max_depth': 30}, mean: 0.72348, std: 0.11612, params: {'min_samples_split': 6, 'n_estimators': 63, 'max_depth': 30}, mean: 0.72453, std: 0.11459, params: {'min_samples_split': 6, 'n_estimators': 64, 'max_depth': 30}, mean: 0.72509, std: 0.11479, params: {'min_samples_split': 6, 'n_estimators': 65, 'max_depth': 30}, mean: 0.72670, std: 0.11525, params: {'min_samples_split': 7, 'n_estimators': 61, 'max_depth': 30}, mean: 0.72645, std: 0.11593, params: {'min_samples_split': 7, 'n_estimators': 62, 'max_depth': 30}, mean: 0.72627, std: 0.11542, params: {'min_samples_split': 7, 'n_estimators': 63, 'max_depth': 30}, mean: 0.72639, std: 0.11552, params: {'min_samples_split': 7, 'n_estimators': 64, 'max_depth': 30}, mean: 0.72429, std: 0.11585, params: {'min_samples_split': 7, 'n_estimators': 65, 'max_depth': 30}, mean: 0.72181, std: 0.11494, params: {'min_samples_split': 8, 'n_estimators': 61, 'max_depth': 30}, mean: 0.72268, std: 0.11493, params: {'min_samples_split': 8, 'n_estimators': 62, 'max_depth': 30}, mean: 0.72299, std: 0.11374, params: {'min_samples_split': 8, 'n_estimators': 63, 'max_depth': 30}, mean: 0.72070, std: 0.11550, params: {'min_samples_split': 8, 'n_estimators': 64, 'max_depth': 30}, mean: 0.72546, std: 0.11448, params: {'min_samples_split': 8, 'n_estimators': 65, 'max_depth': 30}, mean: 0.72596, std: 0.10991, params: {'min_samples_split': 4, 'n_estimators': 61, 'max_depth': 31}, mean: 0.72608, std: 0.11009, params: {'min_samples_split': 4, 'n_estimators': 62, 'max_depth': 31}, mean: 0.72435, std: 0.11136, params: {'min_samples_split': 4, 'n_estimators': 63, 'max_depth': 31}, mean: 0.72509, std: 0.11062, params: {'min_samples_split': 4, 'n_estimators': 64, 'max_depth': 31}, mean: 0.72608, std: 0.11133, params: {'min_samples_split': 4, 'n_estimators': 65, 'max_depth': 31}, mean: 0.72410, std: 0.11295, params: {'min_samples_split': 5, 'n_estimators': 61, 'max_depth': 31}, mean: 0.72336, std: 0.10982, params: {'min_samples_split': 5, 'n_estimators': 62, 'max_depth': 31}, mean: 0.72435, std: 0.11091, params: {'min_samples_split': 5, 'n_estimators': 63, 'max_depth': 31}, mean: 0.72490, std: 0.11117, params: {'min_samples_split': 5, 'n_estimators': 64, 'max_depth': 31}, mean: 0.72385, std: 0.11177, params: {'min_samples_split': 5, 'n_estimators': 65, 'max_depth': 31}, mean: 0.72014, std: 0.11262, params: {'min_samples_split': 6, 'n_estimators': 61, 'max_depth': 31}, mean: 0.72577, std: 0.11189, params: {'min_samples_split': 6, 'n_estimators': 62, 'max_depth': 31}, mean: 0.72589, std: 0.11200, params: {'min_samples_split': 6, 'n_estimators': 63, 'max_depth': 31}, mean: 0.72466, std: 0.11342, params: {'min_samples_split': 6, 'n_estimators': 64, 'max_depth': 31}, mean: 0.72540, st ...
# ############# based on standard predict ################
# Accuracy on training data: 0.88
# Accuracy on test data:     0.77
# [[1813  971]
#  [ 620 3521]]
# ########################################################

# %% [markdown]
# Let us now proceed to print the Top 10 significant features from this model fitted against balanced dataset and compare them against the ones from unbalanced dataset.

# %%
# Create plot of Top 10 significant factors using feature importances

import math
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 6), tight_layout = True)
ax = axes.ravel() 
plt1 = ax[0]

importance_list = clfForest.feature_importances_
name_list = features
importance_list, name_list = zip(*sorted(zip(importance_list, name_list) )[-10:])
plt1.barh(range(len(name_list)),importance_list,align='center')
plt1.set_yticks(range(len(name_list)))
plt1.set_yticklabels(name_list)
plt1.set_xticks([0, 0.14 ,0.28, 0.42])
plt1.set_xlabel('Relative Importance in the Random Forest')
plt1.set_title('Relative importance of Each Feature -\n Unbalanced dataset')


plt2 = ax[1]

importance_list = clfForest_balanced.feature_importances_
name_list = features
importance_list, name_list = zip(*sorted(zip(importance_list, name_list) )[-10:])
plt2.barh(range(len(name_list)),importance_list,align='center')
plt2.set_yticks(range(len(name_list)))
plt2.set_yticklabels(name_list)
plt2.set_xticks([0, 0.04 ,0.08, 0.12])
plt2.set_xlabel('Relative Importance in the Random Forest')
plt2.set_title('Relative importance of Each Feature -\n Balanced dataset')

# %% [markdown]
# The relative importance chart seems to suggest that adjusting for proportions of stolen bikes in Bike Model year helped bump up the significane of other bike related features. The Model Year continues to be the single most important feature. This can probably be explained by the lack of motivation of long time bike owners to register with BikeIndex.org unless in the event their bike gets stolen.

# %% [markdown]
# Finally let us compare the performance of RandomForest on balanced and un-balanced datasets.

# %%
ax = make_roc("Random Forest - balanced",clfForest_balanced, ytest1, Xtest1, None, labe=300, skip=400)
make_roc("Random Forest",clfForest, ytest, Xtest, ax, labe=300, skip=400);

# %%
createOverlappingDistributionPlotOfTargetValuesByColumn( df_clean , 'manufacturer_name' , 'stolen' , 15 , None)

# %%
# References: 1) https://www.bikeexchange.co.nz/article/buying-a-full-size-bike
# 2) http://stackoverflow.com/questions/19867734/changing-certain-values-in-multiple-columns-of-a-pandas-dataframe-at-once
# 3) http://stackoverflow.com/questions/21094288/convert-list-of-rgb-codes-to-matplotlib-colormap
# 4) http://stackoverflow.com/questions/18897261/pandas-plot-dataframe-barplot-with-colors-by-category
# 5) http://stackoverfhttp://stackoverflow.com/questions/23294616/how-to-use-scikit-learn-pca-for-features-reduction-and-know-
# which-features-are-dlow.com/questions/11927715/how-to-give-a-pandas-matplotlib-bar-graph-custom-colors
# 6) http://stackoverflow.com/questions/14207410/trouble-understanding-output-from-scikit-random-forest
# 7) Python Machine Learning Sebastian Raschka
